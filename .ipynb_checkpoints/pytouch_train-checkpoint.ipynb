# %%
import torch
import torchvision
import torchvision.transforms as transforms
from PIL import Image
Image.MAX_IMAGE_PIXELS = None  # Disable DecompressionBombError
import pandas as pd
import os
import matplotlib.pyplot as plt
from skimage import io, transform
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# #### 可以使用torchvision中提供的API快速的创建一个reader实现在训练的过程中不断地读取图像和类别信息
# **transform** 表示把读取的图像resize到227 * 227并转换为PyTorch中的tensor类型，同时将其标准化到\[ -1 , 1 \]之间。

# %%
def read_csv_file():


    DATASET_MEDIUM_DIR = 'can_be_train.csv'
    Image.MAX_IMAGE_PIXELS = None

    imgs_dirs = []
    dataset_read_result = pd.read_csv(DATASET_MEDIUM_DIR)
    i = 0
    for each_img_dir, \
        each_landmarks_dir, \
        each_target_image, \
        each_target_landmarks, \
        each_status in zip(dataset_read_result['Source image'],
                           dataset_read_result['Source landmarks'],
                           dataset_read_result['Target image'],
                           dataset_read_result['Target landmarks'],
                           dataset_read_result['status']):
        each_img_dir = 'images/' + each_img_dir
        each_landmarks_dir = 'landmarks/' + each_landmarks_dir
        each_target_image = 'images/' + each_target_image
        each_target_landmarks = 'landmarks/' + each_target_landmarks

        dataset_read_result.set_value(index=i, col='Source image', value=each_img_dir)
        dataset_read_result.set_value(index=i, col='Source landmarks', value=each_landmarks_dir)
        dataset_read_result.set_value(index=i, col='Target image', value=each_target_image)
        dataset_read_result.set_value(index=i, col='Target landmarks', value=each_target_landmarks)

        imgs_dirs.append(each_img_dir)
        i = i + 1

    print(dataset_read_result['Source image'][1])
    print(imgs_dirs[1])
    return dataset_read_result


dataset_read_result = read_csv_file()

# the first 10
source_image_array = dataset_read_result['Source image']
target_image_array = dataset_read_result['Target image']
source_image_landmarks = dataset_read_result['Source landmarks']
target_image_landmarks = dataset_read_result['Target landmarks']
# Out:
# images/lung-lesion_2/scale-25pc/29-041-Izd2-w35-He-les2.jpg
# images/lung-lesion_2/scale-25pc/29-041-Izd2-w35-He-les2.jpg
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
transform = transforms.Compose(
    [transforms.Resize([227,227]),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

loader = torch.utils.data.DataLoader(source_image_array, batch_size=1,shuffle=True, num_workers=2)

# %%
def show_landmarks(image, X,Y):
    plt.imshow(image)
    plt.scatter(X, Y, s=10, marker='.', c='r')
    plt.pause(0.001)  # pause a bit so that plots are updated

plt.figure()
source_image_1 = source_image_array[0]
source_image_landmark = source_image_landmarks[0]
current = pd.read_csv(source_image_landmark)
X = current['X']
Y = current['Y']

show_landmarks(io.imread(source_image_1),X,Y)
plt.show()

# %% [markdown]
# #### 训练
# 由于开始PIL读取图片导致图片过大，改了PIL文件Image.py中的MAX_IMAGE_PIXELS=none

# %% [markdown]
# 计算 output size feature size
# output = int((in_size - kernel_size + 2*(padding)) / stride) + 1

# %%
def outputSize(in_size, kernel_size, stride, padding):
    output = int((in_size - kernel_size + 2*(padding)) / stride)+1 
    return output
print(outputSize(512,3,2,0))
print(outputSize(255,2,1,0))
# Out:
# 255
# 254

# %%
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

class regNet_2D(nn.Module):
    def __init__(self):
        #使用super()方法调用基类的构造器，即nn.Module.__init__(self)
        super(regNet_2D,self).__init__()
        # The first layer 
        # Input channels = 3, output channels = 6 ,,5x5 square convolution kernel
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1) 
        self.bn1=nn.BatchNorm2d(32)
        self.pool_1 = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.bn2=nn.BatchNorm2d(64)
        self.pool_2 = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        
        
        self.reg_1 = torch.nn.Linear(128 * 16 * 16, 70)
        self.reg_1_1 = torch.nn.Linear(70, 70)
        # self.reg_1_2 = torch.nn.Linear(70, 70)
        
        
        self.deconv1=nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2)
        self.bn_deconv1=nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1)
        self.bn4=nn.BatchNorm2d(64)
        self.reg_2 = torch.nn.Linear(64 * 17 * 17, 70)
        self.reg_2_1 = torch.nn.Linear(70, 70)
        # self.reg_2_2 = torch.nn.Linear(70, 70)
        #64 input features, 10 output features for our 10 defined classes
        # self.fc2 = torch.nn.Linear(78, 78)
        
        ########### end of the first
        self.conv1_y = nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1) 
        self.bn1_y=nn.BatchNorm2d(32)
        self.pool_1_y = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        
        self.conv2_y = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.bn2_y = nn.BatchNorm2d(64)
        self.pool_2_y  = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        self.conv3_y = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        
        self.reg_1_y = torch.nn.Linear(128 * 16 * 16, 70)
        self.reg_1_1_y = torch.nn.Linear(70, 70)
        
        self.deconv1_y = nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2)
        self.bn_deconv1_y = nn.BatchNorm2d(64)
        self.conv4_y = nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1)
        self.bn4_y=nn.BatchNorm2d(64)
        self.reg_2_y = torch.nn.Linear(64 * 17 * 17, 70)
        self.reg_2_1_y = torch.nn.Linear(70, 70)
        
        
    def forward(self,x,y):
        #Size changes from (3, height, weight) to (6, height, weight)
        x = F.relu(self.bn1(self.conv1(x)))
        #Size changes from (6, height, weight) to (6, height/2, weight/2)
        x = self.pool_1(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool_2(x)
        x = F.relu(self.conv3(x))
        #Reshape data to input to the input layer of the neural net
        #Size changes from (6, height/2, weight/2) to (1, 6*height/2*weight/2)
        #Recall that the -1 infers this dimension from the other given dimension
        x_1 = x.view(-1, 128 * 16 * 16)
        #Computes the activation of the first fully connected layer
        #Size changes from (1, 4608) to (1, 78)
        x_1 = self.reg_1(x_1)
        
        
        x = F.relu(self.bn_deconv1(self.deconv1(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x_2 = x.view(-1, 64 * 17 * 17)
        x_2 = self.reg_2(x_2)
        
        #### end of the first image
        
        ### the first guess using the samiliar network
        y = F.relu(self.bn1(self.conv1(y)))
        y = self.pool_1(y)
        y = F.relu(self.bn2(self.conv2(y)))
        y = self.pool_2(y)
        y = F.relu(self.conv3(y))
        
        y_1 = y.view(-1, 128 * 16 * 16)
        y_1 = self.reg_1(y_1)
        
        y = F.relu(self.bn_deconv1(self.deconv1(y)))
        y = F.relu(self.bn4(self.conv4(y)))
        y_2 = y.view(-1, 64 * 17 * 17)
        y_2 = self.reg_2(y_2)
        
        
        
        # x = F.relu(self.fc2(x))
        return x_1,x_2,y_1,y_2

# %%
# transform_1 = transforms.Compose([transforms.Resize([512,512]),transforms.ToTensor()""",transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))"""]) 

transform_1 = transforms.Compose([transforms.Resize([512,512]),
                                  transforms.ToTensor()])


reg_net=regNet_2D()

from PIL import Image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

optimizer = optim.Adam(reg_net.parameters(), lr=1e-4)
loss = nn.L1Loss()# MSELoss可换为
for epoch in range(2):
    for i, data in enumerate(loader, 0):
        inputs = data
        # source_image = plt.imread(inputs[0])
        
        optimizer.zero_grad()
        source_image = Image.open(inputs[0]).convert('RGB')
        # image = transform_1(source_image).unsqueeze(0)
        # width, height = source_image.size
        source_image1 = transform_1(source_image)
        # image_tensor = source_image1.to(device, torch.float)
        # source_image1 = torch.from_numpy(source_image).float()
        # source_image1 = source_image1.type(torch.FloatTensor)
        image_tensor= source_image1.unsqueeze(0)
        
        image_tensor = Variable(image_tensor)
        
        
        
        target_image = Image.open(target_image_array[i]).convert('RGB')
        # image = transform_1(target_image).unsqueeze(0)
        target_image1 = transform_1(target_image)
        target_image_tensor= target_image1.unsqueeze(0)
        target_image_tensor = Variable(target_image_tensor)
        
        optimizer.zero_grad()
        
        
        
        x_1,x_2,y_1,y_2 = reg_net(image_tensor,target_image_tensor)
        # plt.imshow(image)
        # plt.imshow(target_image)
        source_image_landmark = source_image_landmarks[i]
        current = pd.read_csv(source_image_landmark)
        X = current['X']
        Y = current['Y']
        # X = X.transpose()
        X = torch.FloatTensor(X[:70])
        X = X.unsqueeze(0)
        
        Y = torch.FloatTensor(Y[:70])
        Y = Y.unsqueeze(0)
        loss_1 = loss(x_1, X)
        loss_2 = loss(x_2, Y)
        
        ######
        target_image_landmark = target_image_landmarks[i]
        current = pd.read_csv(target_image_landmark)
        X = current['X']
        Y = current['Y']
        
        X = torch.FloatTensor(X[:70])
        X = X.unsqueeze(0)
        
        Y = torch.FloatTensor(Y[:70])
        Y = Y.unsqueeze(0)
        
        loss_3 = loss(y_1, X)
        loss_4 = loss(y_2, Y)
        
        
        loss_all = loss_1+loss_2+loss_3+loss_4
        loss_all.backward()
        
        optimizer.step()
        print("The loss is ",loss_all)
        
    
print(x_1)
# Out:
# The loss is  tensor(12843.9072, grad_fn=<AddBackward0>)
# The loss is  tensor(12749.5850, grad_fn=<AddBackward0>)
# The loss is  tensor(12683.0732, grad_fn=<AddBackward0>)
# The loss is  tensor(12483.6260, grad_fn=<AddBackward0>)
# The loss is  tensor(12392.4902, grad_fn=<AddBackward0>)
# The loss is  tensor(12325.6250, grad_fn=<AddBackward0>)
# The loss is  tensor(12126.1855, grad_fn=<AddBackward0>)
# The loss is  tensor(12227.4209, grad_fn=<AddBackward0>)
# The loss is  tensor(12027.9854, grad_fn=<AddBackward0>)
# The loss is  tensor(11960.1221, grad_fn=<AddBackward0>)
# The loss is  tensor(16618.8477, grad_fn=<AddBackward0>)
# The loss is  tensor(16012.1328, grad_fn=<AddBackward0>)
# The loss is  tensor(15842.0498, grad_fn=<AddBackward0>)
# The loss is  tensor(16662.8652, grad_fn=<AddBackward0>)
# The loss is  tensor(15506.4023, grad_fn=<AddBackward0>)
# The loss is  tensor(15334.0518, grad_fn=<AddBackward0>)
# The loss is  tensor(16149.8447, grad_fn=<AddBackward0>)
# The loss is  tensor(14714.2422, grad_fn=<AddBackward0>)
# The loss is  tensor(15535.8633, grad_fn=<AddBackward0>)
# The loss is  tensor(15360.4844, grad_fn=<AddBackward0>)
# The loss is  tensor(14556.8711, grad_fn=<AddBackward0>)
# The loss is  tensor(14581.3770, grad_fn=<AddBackward0>)
# The loss is  tensor(14611.5176, grad_fn=<AddBackward0>)
# The loss is  tensor(14967.0703, grad_fn=<AddBackward0>)
# The loss is  tensor(14854.0889, grad_fn=<AddBackward0>)
# The loss is  tensor(14880.9307, grad_fn=<AddBackward0>)
# The loss is  tensor(15249.1602, grad_fn=<AddBackward0>)
# The loss is  tensor(14889.0322, grad_fn=<AddBackward0>)
# The loss is  tensor(15247.8154, grad_fn=<AddBackward0>)
# The loss is  tensor(15267.2500, grad_fn=<AddBackward0>)
# The loss is  tensor(4956.7949, grad_fn=<AddBackward0>)
# The loss is  tensor(5078.9580, grad_fn=<AddBackward0>)
# The loss is  tensor(5220.7769, grad_fn=<AddBackward0>)
# The loss is  tensor(4884.2915, grad_fn=<AddBackward0>)
# The loss is  tensor(4452.4160, grad_fn=<AddBackward0>)
# The loss is  tensor(4623.3408, grad_fn=<AddBackward0>)
# The loss is  tensor(4249.1675, grad_fn=<AddBackward0>)
# The loss is  tensor(4716.9512, grad_fn=<AddBackward0>)
# The loss is  tensor(4387.3477, grad_fn=<AddBackward0>)
# The loss is  tensor(4535.4468, grad_fn=<AddBackward0>)
# The loss is  tensor(6881.8994, grad_fn=<AddBackward0>)
# The loss is  tensor(6831.7739, grad_fn=<AddBackward0>)
# The loss is  tensor(6838.1528, grad_fn=<AddBackward0>)
# The loss is  tensor(6976.5254, grad_fn=<AddBackward0>)
# The loss is  tensor(6766.1968, grad_fn=<AddBackward0>)
# The loss is  tensor(6785.2441, grad_fn=<AddBackward0>)
# The loss is  tensor(6912.1748, grad_fn=<AddBackward0>)
# The loss is  tensor(6711.8145, grad_fn=<AddBackward0>)
# The loss is  tensor(6836.3281, grad_fn=<AddBackward0>)
# The loss is  tensor(6851.6338, grad_fn=<AddBackward0>)
# The loss is  tensor(7775.9375, grad_fn=<AddBackward0>)
# The loss is  tensor(7763.5322, grad_fn=<AddBackward0>)
# The loss is  tensor(7773.6802, grad_fn=<AddBackward0>)
# The loss is  tensor(7517.2231, grad_fn=<AddBackward0>)
# The loss is  tensor(7615.8813, grad_fn=<AddBackward0>)
# The loss is  tensor(7739.6367, grad_fn=<AddBackward0>)
# The loss is  tensor(7423.9263, grad_fn=<AddBackward0>)
# The loss is  tensor(7628.5371, grad_fn=<AddBackward0>)
# The loss is  tensor(7355.5244, grad_fn=<AddBackward0>)
# The loss is  tensor(7442.9404, grad_fn=<AddBackward0>)
# The loss is  tensor(5546.4307, grad_fn=<AddBackward0>)
# The loss is  tensor(5350.1641, grad_fn=<AddBackward0>)
# The loss is  tensor(5512.4761, grad_fn=<AddBackward0>)
# The loss is  tensor(5331.8638, grad_fn=<AddBackward0>)
# The loss is  tensor(5337.8843, grad_fn=<AddBackward0>)
# The loss is  tensor(5470.9941, grad_fn=<AddBackward0>)
# The loss is  tensor(5295.8735, grad_fn=<AddBackward0>)
# The loss is  tensor(5305.9355, grad_fn=<AddBackward0>)
# The loss is  tensor(5058.9863, grad_fn=<AddBackward0>)
# The loss is  tensor(5251.6694, grad_fn=<AddBackward0>)
# The loss is  tensor(6948.2363, grad_fn=<AddBackward0>)
# The loss is  tensor(7137.2285, grad_fn=<AddBackward0>)
# The loss is  tensor(6795.3774, grad_fn=<AddBackward0>)
# The loss is  tensor(7022.8750, grad_fn=<AddBackward0>)
# The loss is  tensor(6671.7026, grad_fn=<AddBackward0>)
# The loss is  tensor(6268.9526, grad_fn=<AddBackward0>)
# The loss is  tensor(6593.6763, grad_fn=<AddBackward0>)
# The loss is  tensor(6504.4775, grad_fn=<AddBackward0>)
# The loss is  tensor(6820.6885, grad_fn=<AddBackward0>)
# The loss is  tensor(6236.1309, grad_fn=<AddBackward0>)
# The loss is  tensor(10569.1426, grad_fn=<AddBackward0>)
# The loss is  tensor(11323.3066, grad_fn=<AddBackward0>)
# The loss is  tensor(10604.8867, grad_fn=<AddBackward0>)
# The loss is  tensor(11411.8027, grad_fn=<AddBackward0>)
# The loss is  tensor(11427.5342, grad_fn=<AddBackward0>)
# The loss is  tensor(11404.9912, grad_fn=<AddBackward0>)
# The loss is  tensor(10941.2461, grad_fn=<AddBackward0>)
# The loss is  tensor(9712.0869, grad_fn=<AddBackward0>)
# The loss is  tensor(9015.8818, grad_fn=<AddBackward0>)
# The loss is  tensor(9880.4561, grad_fn=<AddBackward0>)
# The loss is  tensor(9735.8262, grad_fn=<AddBackward0>)
# The loss is  tensor(9778.3115, grad_fn=<AddBackward0>)
# The loss is  tensor(9319.7930, grad_fn=<AddBackward0>)
# The loss is  tensor(9714.2109, grad_fn=<AddBackward0>)
# The loss is  tensor(10326.5850, grad_fn=<AddBackward0>)
# The loss is  tensor(10328.1553, grad_fn=<AddBackward0>)
# The loss is  tensor(10313.9326, grad_fn=<AddBackward0>)
# The loss is  tensor(9947.3867, grad_fn=<AddBackward0>)
# The loss is  tensor(9500.8320, grad_fn=<AddBackward0>)
# The loss is  tensor(9353.0547, grad_fn=<AddBackward0>)
# The loss is  tensor(9182.8115, grad_fn=<AddBackward0>)
# The loss is  tensor(8842.8047, grad_fn=<AddBackward0>)
# The loss is  tensor(10018.4590, grad_fn=<AddBackward0>)
# The loss is  tensor(10149.3398, grad_fn=<AddBackward0>)
# The loss is  tensor(9468.0742, grad_fn=<AddBackward0>)
# The loss is  tensor(9725.8418, grad_fn=<AddBackward0>)
# The loss is  tensor(9355.2451, grad_fn=<AddBackward0>)
# The loss is  tensor(9081.9570, grad_fn=<AddBackward0>)
# The loss is  tensor(8742.4170, grad_fn=<AddBackward0>)
# The loss is  tensor(8505.6738, grad_fn=<AddBackward0>)
# The loss is  tensor(8391.1074, grad_fn=<AddBackward0>)
# The loss is  tensor(8070.2803, grad_fn=<AddBackward0>)
# The loss is  tensor(8006.1680, grad_fn=<AddBackward0>)
# The loss is  tensor(7892.5615, grad_fn=<AddBackward0>)
# The loss is  tensor(7396.4136, grad_fn=<AddBackward0>)
# The loss is  tensor(7404.6255, grad_fn=<AddBackward0>)
# The loss is  tensor(7077.3486, grad_fn=<AddBackward0>)
# The loss is  tensor(6908.9995, grad_fn=<AddBackward0>)
# The loss is  tensor(11760.5518, grad_fn=<AddBackward0>)
# The loss is  tensor(11220.1475, grad_fn=<AddBackward0>)
# The loss is  tensor(10887.7051, grad_fn=<AddBackward0>)
# The loss is  tensor(11672.9355, grad_fn=<AddBackward0>)
# The loss is  tensor(10691.5371, grad_fn=<AddBackward0>)
# The loss is  tensor(10546.4844, grad_fn=<AddBackward0>)
# The loss is  tensor(11275.1094, grad_fn=<AddBackward0>)
# The loss is  tensor(9798.3848, grad_fn=<AddBackward0>)
# The loss is  tensor(10655.0420, grad_fn=<AddBackward0>)
# The loss is  tensor(10138.3027, grad_fn=<AddBackward0>)
# The loss is  tensor(9938.4346, grad_fn=<AddBackward0>)
# The loss is  tensor(9850.9766, grad_fn=<AddBackward0>)
# The loss is  tensor(9633.0859, grad_fn=<AddBackward0>)
# The loss is  tensor(9941.6387, grad_fn=<AddBackward0>)
# The loss is  tensor(10306.1572, grad_fn=<AddBackward0>)
# The loss is  tensor(10129.5723, grad_fn=<AddBackward0>)
# The loss is  tensor(10512.3145, grad_fn=<AddBackward0>)
# The loss is  tensor(10025.5879, grad_fn=<AddBackward0>)
# The loss is  tensor(10342.3477, grad_fn=<AddBackward0>)
# The loss is  tensor(10014.4844, grad_fn=<AddBackward0>)
# The loss is  tensor(7595.3223, grad_fn=<AddBackward0>)
# The loss is  tensor(8053.5171, grad_fn=<AddBackward0>)
# The loss is  tensor(8020.7285, grad_fn=<AddBackward0>)
# The loss is  tensor(7669.5933, grad_fn=<AddBackward0>)
# The loss is  tensor(8068.9307, grad_fn=<AddBackward0>)
# The loss is  tensor(7881.4976, grad_fn=<AddBackward0>)
# The loss is  tensor(7713.9282, grad_fn=<AddBackward0>)
# The loss is  tensor(7429.3623, grad_fn=<AddBackward0>)
# The loss is  tensor(7436.5508, grad_fn=<AddBackward0>)
# The loss is  tensor(7130.1055, grad_fn=<AddBackward0>)
# The loss is  tensor(8107.2319, grad_fn=<AddBackward0>)
# The loss is  tensor(7318.4199, grad_fn=<AddBackward0>)
# The loss is  tensor(7273.7324, grad_fn=<AddBackward0>)
# The loss is  tensor(7409.1074, grad_fn=<AddBackward0>)
# The loss is  tensor(7352.1440, grad_fn=<AddBackward0>)
# The loss is  tensor(6856.5063, grad_fn=<AddBackward0>)
# The loss is  tensor(6337.2358, grad_fn=<AddBackward0>)
# The loss is  tensor(6332.6011, grad_fn=<AddBackward0>)
# The loss is  tensor(6079.0508, grad_fn=<AddBackward0>)
# The loss is  tensor(5972.2197, grad_fn=<AddBackward0>)
# The loss is  tensor(7324.8613, grad_fn=<AddBackward0>)
# The loss is  tensor(7352.8623, grad_fn=<AddBackward0>)
# The loss is  tensor(7239.2246, grad_fn=<AddBackward0>)
# The loss is  tensor(6780.2373, grad_fn=<AddBackward0>)
# The loss is  tensor(6837.6348, grad_fn=<AddBackward0>)
# The loss is  tensor(6885.6172, grad_fn=<AddBackward0>)
# The loss is  tensor(6427.0508, grad_fn=<AddBackward0>)
# The loss is  tensor(6690.0498, grad_fn=<AddBackward0>)
# The loss is  tensor(6781.4189, grad_fn=<AddBackward0>)
# The loss is  tensor(6484.2998, grad_fn=<AddBackward0>)
# The loss is  tensor(4870.8428, grad_fn=<AddBackward0>)
# The loss is  tensor(4854.7441, grad_fn=<AddBackward0>)
# The loss is  tensor(5180.2915, grad_fn=<AddBackward0>)
# The loss is  tensor(4803.5020, grad_fn=<AddBackward0>)
# The loss is  tensor(4742.7827, grad_fn=<AddBackward0>)
# The loss is  tensor(4779.9585, grad_fn=<AddBackward0>)
# The loss is  tensor(4690.8696, grad_fn=<AddBackward0>)
# The loss is  tensor(4947.2188, grad_fn=<AddBackward0>)
# The loss is  tensor(4797.1436, grad_fn=<AddBackward0>)
# The loss is  tensor(4741.6479, grad_fn=<AddBackward0>)
# The loss is  tensor(5930.6694, grad_fn=<AddBackward0>)
# The loss is  tensor(6024.7622, grad_fn=<AddBackward0>)
# The loss is  tensor(5646.9033, grad_fn=<AddBackward0>)
# The loss is  tensor(6061.7808, grad_fn=<AddBackward0>)
# The loss is  tensor(5846.2080, grad_fn=<AddBackward0>)
# The loss is  tensor(5519.3896, grad_fn=<AddBackward0>)
# The loss is  tensor(5627.5254, grad_fn=<AddBackward0>)
# The loss is  tensor(5593.3789, grad_fn=<AddBackward0>)
# The loss is  tensor(6029.8418, grad_fn=<AddBackward0>)
# The loss is  tensor(5451.3232, grad_fn=<AddBackward0>)
# The loss is  tensor(9557.0156, grad_fn=<AddBackward0>)
# The loss is  tensor(10690.2725, grad_fn=<AddBackward0>)
# The loss is  tensor(9896.1230, grad_fn=<AddBackward0>)
# The loss is  tensor(10778.3818, grad_fn=<AddBackward0>)
# The loss is  tensor(10499.0010, grad_fn=<AddBackward0>)
# The loss is  tensor(10620.1328, grad_fn=<AddBackward0>)
# The loss is  tensor(10410.9795, grad_fn=<AddBackward0>)
# The loss is  tensor(8556.7305, grad_fn=<AddBackward0>)
# The loss is  tensor(8429.2881, grad_fn=<AddBackward0>)
# The loss is  tensor(9319.0283, grad_fn=<AddBackward0>)
# The loss is  tensor(8980.2676, grad_fn=<AddBackward0>)
# The loss is  tensor(9090.7119, grad_fn=<AddBackward0>)
# The loss is  tensor(8907.8086, grad_fn=<AddBackward0>)
# The loss is  tensor(9411.9258, grad_fn=<AddBackward0>)
# The loss is  tensor(9995.0459, grad_fn=<AddBackward0>)
# The loss is  tensor(10070.3848, grad_fn=<AddBackward0>)
# The loss is  tensor(9993.4082, grad_fn=<AddBackward0>)
# The loss is  tensor(9568.0742, grad_fn=<AddBackward0>)
# The loss is  tensor(9296.5596, grad_fn=<AddBackward0>)
# The loss is  tensor(9210.6250, grad_fn=<AddBackward0>)
# The loss is  tensor(8689.8906, grad_fn=<AddBackward0>)
# The loss is  tensor(8771.8096, grad_fn=<AddBackward0>)
# The loss is  tensor(10036.7510, grad_fn=<AddBackward0>)
# The loss is  tensor(9893.8867, grad_fn=<AddBackward0>)
# The loss is  tensor(9501.8975, grad_fn=<AddBackward0>)
# The loss is  tensor(9671.9736, grad_fn=<AddBackward0>)
# The loss is  tensor(9262.5928, grad_fn=<AddBackward0>)
# The loss is  tensor(8583.4561, grad_fn=<AddBackward0>)
# The loss is  tensor(8483.6182, grad_fn=<AddBackward0>)
# The loss is  tensor(7742.9199, grad_fn=<AddBackward0>)
# The loss is  tensor(8120.7739, grad_fn=<AddBackward0>)
# The loss is  tensor(7797.4404, grad_fn=<AddBackward0>)
# The loss is  tensor(7713.3877, grad_fn=<AddBackward0>)
# The loss is  tensor(7419.2437, grad_fn=<AddBackward0>)
# The loss is  tensor(6686.1904, grad_fn=<AddBackward0>)
# The loss is  tensor(6533.7881, grad_fn=<AddBackward0>)
# The loss is  tensor(6358.9043, grad_fn=<AddBackward0>)
# The loss is  tensor(6677.4609, grad_fn=<AddBackward0>)
# The loss is  tensor(11194.5527, grad_fn=<AddBackward0>)
# The loss is  tensor(10744.2109, grad_fn=<AddBackward0>)
# The loss is  tensor(10078.7861, grad_fn=<AddBackward0>)
# The loss is  tensor(11114.9424, grad_fn=<AddBackward0>)
# The loss is  tensor(10267.0791, grad_fn=<AddBackward0>)
# The loss is  tensor(9964.6133, grad_fn=<AddBackward0>)
# The loss is  tensor(10248.3105, grad_fn=<AddBackward0>)
# The loss is  tensor(9310.5039, grad_fn=<AddBackward0>)
# The loss is  tensor(9756.4082, grad_fn=<AddBackward0>)
# The loss is  tensor(9351.4424, grad_fn=<AddBackward0>)
# The loss is  tensor(9484.7188, grad_fn=<AddBackward0>)
# The loss is  tensor(9420.7607, grad_fn=<AddBackward0>)
# The loss is  tensor(9321.7383, grad_fn=<AddBackward0>)
# The loss is  tensor(9541.3457, grad_fn=<AddBackward0>)
# The loss is  tensor(9997.1875, grad_fn=<AddBackward0>)
# The loss is  tensor(9907.4053, grad_fn=<AddBackward0>)
# The loss is  tensor(10159.7637, grad_fn=<AddBackward0>)
# The loss is  tensor(9559.3594, grad_fn=<AddBackward0>)
# The loss is  tensor(9791.4980, grad_fn=<AddBackward0>)
# The loss is  tensor(9747.4355, grad_fn=<AddBackward0>)
# The loss is  tensor(7318.3135, grad_fn=<AddBackward0>)
# The loss is  tensor(7251.9980, grad_fn=<AddBackward0>)
# The loss is  tensor(7096.7856, grad_fn=<AddBackward0>)
# The loss is  tensor(7297.6582, grad_fn=<AddBackward0>)
# The loss is  tensor(7898.6826, grad_fn=<AddBackward0>)
# The loss is  tensor(7269.1382, grad_fn=<AddBackward0>)
# The loss is  tensor(7121.1523, grad_fn=<AddBackward0>)
# The loss is  tensor(7945.7212, grad_fn=<AddBackward0>)
# The loss is  tensor(7643.7676, grad_fn=<AddBackward0>)
# The loss is  tensor(6927.8506, grad_fn=<AddBackward0>)
# The loss is  tensor(7656.6294, grad_fn=<AddBackward0>)
# The loss is  tensor(7484.3701, grad_fn=<AddBackward0>)
# The loss is  tensor(7292.5449, grad_fn=<AddBackward0>)
# The loss is  tensor(6867.3311, grad_fn=<AddBackward0>)
# The loss is  tensor(6900.2007, grad_fn=<AddBackward0>)
# The loss is  tensor(7504.7261, grad_fn=<AddBackward0>)
# The loss is  tensor(6517.0508, grad_fn=<AddBackward0>)
# The loss is  tensor(6636.0444, grad_fn=<AddBackward0>)
# The loss is  tensor(6363.6963, grad_fn=<AddBackward0>)
# The loss is  tensor(7082.6855, grad_fn=<AddBackward0>)
# The loss is  tensor(7491.8047, grad_fn=<AddBackward0>)
# The loss is  tensor(8169.2017, grad_fn=<AddBackward0>)
# The loss is  tensor(8446.5469, grad_fn=<AddBackward0>)
# The loss is  tensor(7219.0063, grad_fn=<AddBackward0>)
# The loss is  tensor(7128.1343, grad_fn=<AddBackward0>)
# The loss is  tensor(8080.7529, grad_fn=<AddBackward0>)
# The loss is  tensor(6816.9131, grad_fn=<AddBackward0>)
# The loss is  tensor(6927.3701, grad_fn=<AddBackward0>)
# The loss is  tensor(6633.0850, grad_fn=<AddBackward0>)
# The loss is  tensor(6659.6157, grad_fn=<AddBackward0>)
# The loss is  tensor(5090.0879, grad_fn=<AddBackward0>)
# The loss is  tensor(5086.8770, grad_fn=<AddBackward0>)
# The loss is  tensor(5794.9395, grad_fn=<AddBackward0>)
# The loss is  tensor(4966.4033, grad_fn=<AddBackward0>)
# The loss is  tensor(4818.9219, grad_fn=<AddBackward0>)
# The loss is  tensor(4859.2422, grad_fn=<AddBackward0>)
# The loss is  tensor(4768.5698, grad_fn=<AddBackward0>)
# The loss is  tensor(4777.6392, grad_fn=<AddBackward0>)
# The loss is  tensor(4955.6816, grad_fn=<AddBackward0>)
# The loss is  tensor(4780.7417, grad_fn=<AddBackward0>)
# The loss is  tensor(5537.3130, grad_fn=<AddBackward0>)
# The loss is  tensor(5668.9272, grad_fn=<AddBackward0>)
# The loss is  tensor(5159.4414, grad_fn=<AddBackward0>)
# The loss is  tensor(5651.7222, grad_fn=<AddBackward0>)
# The loss is  tensor(5488.2217, grad_fn=<AddBackward0>)
# The loss is  tensor(5175.4082, grad_fn=<AddBackward0>)
# The loss is  tensor(5540.0498, grad_fn=<AddBackward0>)
# The loss is  tensor(5209.5137, grad_fn=<AddBackward0>)
# The loss is  tensor(5433.1343, grad_fn=<AddBackward0>)
# The loss is  tensor(5074.1118, grad_fn=<AddBackward0>)
# The loss is  tensor(8871.3096, grad_fn=<AddBackward0>)
# The loss is  tensor(9918.8857, grad_fn=<AddBackward0>)
# The loss is  tensor(9377.9385, grad_fn=<AddBackward0>)
# The loss is  tensor(10253.3359, grad_fn=<AddBackward0>)
# The loss is  tensor(10187.1719, grad_fn=<AddBackward0>)
# The loss is  tensor(10149.5488, grad_fn=<AddBackward0>)
# The loss is  tensor(9832.8896, grad_fn=<AddBackward0>)
# The loss is  tensor(8653.9453, grad_fn=<AddBackward0>)
# The loss is  tensor(7955.5625, grad_fn=<AddBackward0>)
# The loss is  tensor(8471.4824, grad_fn=<AddBackward0>)
# The loss is  tensor(8750.5654, grad_fn=<AddBackward0>)
# The loss is  tensor(8731.9990, grad_fn=<AddBackward0>)
# The loss is  tensor(8407.7568, grad_fn=<AddBackward0>)
# The loss is  tensor(8792.3428, grad_fn=<AddBackward0>)
# The loss is  tensor(9554.8193, grad_fn=<AddBackward0>)
# The loss is  tensor(9264.4980, grad_fn=<AddBackward0>)
# The loss is  tensor(9473.0693, grad_fn=<AddBackward0>)
# The loss is  tensor(9199.7461, grad_fn=<AddBackward0>)
# The loss is  tensor(8793.1270, grad_fn=<AddBackward0>)
# The loss is  tensor(8411.1855, grad_fn=<AddBackward0>)
# The loss is  tensor(8304.8135, grad_fn=<AddBackward0>)
# The loss is  tensor(8290.6504, grad_fn=<AddBackward0>)
# The loss is  tensor(9164.4834, grad_fn=<AddBackward0>)
# The loss is  tensor(9185.5381, grad_fn=<AddBackward0>)
# The loss is  tensor(8990.2207, grad_fn=<AddBackward0>)
# The loss is  tensor(9112.6973, grad_fn=<AddBackward0>)
# The loss is  tensor(8917.1318, grad_fn=<AddBackward0>)
# The loss is  tensor(8663.6045, grad_fn=<AddBackward0>)
# The loss is  tensor(7124.2686, grad_fn=<AddBackward0>)
# The loss is  tensor(7697.2075, grad_fn=<AddBackward0>)
# The loss is  tensor(7704.7168, grad_fn=<AddBackward0>)
# The loss is  tensor(7432.0508, grad_fn=<AddBackward0>)
# The loss is  tensor(7122.1318, grad_fn=<AddBackward0>)
# The loss is  tensor(7143.9731, grad_fn=<AddBackward0>)
# The loss is  tensor(6885.6406, grad_fn=<AddBackward0>)
# The loss is  tensor(6656.7188, grad_fn=<AddBackward0>)
# The loss is  tensor(6388.4360, grad_fn=<AddBackward0>)
# The loss is  tensor(5712.0747, grad_fn=<AddBackward0>)
# The loss is  tensor(10662.8398, grad_fn=<AddBackward0>)
# The loss is  tensor(10071.5645, grad_fn=<AddBackward0>)
# The loss is  tensor(9955.8125, grad_fn=<AddBackward0>)
# The loss is  tensor(10326.0371, grad_fn=<AddBackward0>)
# The loss is  tensor(9836.9658, grad_fn=<AddBackward0>)
# The loss is  tensor(9172.2637, grad_fn=<AddBackward0>)
# The loss is  tensor(10315.1201, grad_fn=<AddBackward0>)
# The loss is  tensor(8893.0645, grad_fn=<AddBackward0>)
# The loss is  tensor(9703.4160, grad_fn=<AddBackward0>)
# The loss is  tensor(8960.8594, grad_fn=<AddBackward0>)
# The loss is  tensor(9037.5234, grad_fn=<AddBackward0>)
# The loss is  tensor(8970.9961, grad_fn=<AddBackward0>)
# The loss is  tensor(8830.0039, grad_fn=<AddBackward0>)
# The loss is  tensor(9086., grad_fn=<AddBackward0>)
# The loss is  tensor(9973.1953, grad_fn=<AddBackward0>)
# The loss is  tensor(9725.1660, grad_fn=<AddBackward0>)
# The loss is  tensor(10128.1309, grad_fn=<AddBackward0>)
# The loss is  tensor(9528.8428, grad_fn=<AddBackward0>)
# The loss is  tensor(9848.5908, grad_fn=<AddBackward0>)
# The loss is  tensor(9679.9707, grad_fn=<AddBackward0>)
# The loss is  tensor(7651.0205, grad_fn=<AddBackward0>)
# The loss is  tensor(6783.1509, grad_fn=<AddBackward0>)
# The loss is  tensor(6930.1138, grad_fn=<AddBackward0>)
# The loss is  tensor(7091.0820, grad_fn=<AddBackward0>)
# The loss is  tensor(7557.1914, grad_fn=<AddBackward0>)
# The loss is  tensor(7567.0806, grad_fn=<AddBackward0>)
# The loss is  tensor(7452.3315, grad_fn=<AddBackward0>)
# The loss is  tensor(7296.3179, grad_fn=<AddBackward0>)
# The loss is  tensor(7294.3564, grad_fn=<AddBackward0>)
# The loss is  tensor(7145.5332, grad_fn=<AddBackward0>)
# The loss is  tensor(7110.5718, grad_fn=<AddBackward0>)
# The loss is  tensor(7140.8882, grad_fn=<AddBackward0>)
# The loss is  tensor(6829.7007, grad_fn=<AddBackward0>)
# The loss is  tensor(6817.7710, grad_fn=<AddBackward0>)
# The loss is  tensor(7516.7275, grad_fn=<AddBackward0>)
# The loss is  tensor(6553.3315, grad_fn=<AddBackward0>)
# The loss is  tensor(6302.2271, grad_fn=<AddBackward0>)
# The loss is  tensor(6496.7715, grad_fn=<AddBackward0>)
# The loss is  tensor(6100.4155, grad_fn=<AddBackward0>)
# The loss is  tensor(6297.4082, grad_fn=<AddBackward0>)
# The loss is  tensor(7657.9609, grad_fn=<AddBackward0>)
# The loss is  tensor(8483.5703, grad_fn=<AddBackward0>)
# The loss is  tensor(8676.7393, grad_fn=<AddBackward0>)
# The loss is  tensor(7104.0522, grad_fn=<AddBackward0>)
# The loss is  tensor(7512.6929, grad_fn=<AddBackward0>)
# The loss is  tensor(7345.8750, grad_fn=<AddBackward0>)
# The loss is  tensor(7116.4668, grad_fn=<AddBackward0>)
# The loss is  tensor(7117.7881, grad_fn=<AddBackward0>)
# The loss is  tensor(6740.9673, grad_fn=<AddBackward0>)
# The loss is  tensor(7027.1729, grad_fn=<AddBackward0>)
# The loss is  tensor(5299.6880, grad_fn=<AddBackward0>)
# The loss is  tensor(5137.1006, grad_fn=<AddBackward0>)
# The loss is  tensor(5108.6216, grad_fn=<AddBackward0>)
# The loss is  tensor(5133.7168, grad_fn=<AddBackward0>)
# The loss is  tensor(4977.3115, grad_fn=<AddBackward0>)
# The loss is  tensor(5284.8125, grad_fn=<AddBackward0>)
# The loss is  tensor(4981.6689, grad_fn=<AddBackward0>)
# The loss is  tensor(4896.3223, grad_fn=<AddBackward0>)
# The loss is  tensor(5041.8643, grad_fn=<AddBackward0>)
# The loss is  tensor(4878.4243, grad_fn=<AddBackward0>)
# The loss is  tensor(5256.6021, grad_fn=<AddBackward0>)
# The loss is  tensor(5344.2026, grad_fn=<AddBackward0>)
# The loss is  tensor(5037.2861, grad_fn=<AddBackward0>)
# The loss is  tensor(5326.9082, grad_fn=<AddBackward0>)
# The loss is  tensor(4913.2031, grad_fn=<AddBackward0>)
# The loss is  tensor(4874.2651, grad_fn=<AddBackward0>)
# The loss is  tensor(5193.3682, grad_fn=<AddBackward0>)
# The loss is  tensor(4826.1616, grad_fn=<AddBackward0>)
# The loss is  tensor(4973.3999, grad_fn=<AddBackward0>)
# The loss is  tensor(4773.3765, grad_fn=<AddBackward0>)
# The loss is  tensor(8749.3701, grad_fn=<AddBackward0>)
# The loss is  tensor(8960.1064, grad_fn=<AddBackward0>)
# The loss is  tensor(9041.0781, grad_fn=<AddBackward0>)
# The loss is  tensor(9813.4004, grad_fn=<AddBackward0>)
# The loss is  tensor(9750.9541, grad_fn=<AddBackward0>)
# The loss is  tensor(9830.4160, grad_fn=<AddBackward0>)
# The loss is  tensor(9577.6465, grad_fn=<AddBackward0>)
# The loss is  tensor(8330.2363, grad_fn=<AddBackward0>)
# The loss is  tensor(7500.8232, grad_fn=<AddBackward0>)
# The loss is  tensor(8427.8203, grad_fn=<AddBackward0>)
# The loss is  tensor(8430.4912, grad_fn=<AddBackward0>)
# The loss is  tensor(7643.8594, grad_fn=<AddBackward0>)
# The loss is  tensor(8054.8584, grad_fn=<AddBackward0>)
# The loss is  tensor(8192.4482, grad_fn=<AddBackward0>)
# The loss is  tensor(9304.0215, grad_fn=<AddBackward0>)
# The loss is  tensor(9198.5342, grad_fn=<AddBackward0>)
# The loss is  tensor(9132.6602, grad_fn=<AddBackward0>)
# The loss is  tensor(8862.2012, grad_fn=<AddBackward0>)
# The loss is  tensor(7756.6606, grad_fn=<AddBackward0>)
# The loss is  tensor(8469.5146, grad_fn=<AddBackward0>)
# The loss is  tensor(7901.3257, grad_fn=<AddBackward0>)
# The loss is  tensor(7939.2852, grad_fn=<AddBackward0>)
# The loss is  tensor(8763.4844, grad_fn=<AddBackward0>)
# The loss is  tensor(9139.6787, grad_fn=<AddBackward0>)
# The loss is  tensor(8768.2100, grad_fn=<AddBackward0>)
# The loss is  tensor(8829.3633, grad_fn=<AddBackward0>)
# The loss is  tensor(8541.4678, grad_fn=<AddBackward0>)
# The loss is  tensor(8495.4150, grad_fn=<AddBackward0>)
# The loss is  tensor(7594.7617, grad_fn=<AddBackward0>)
# The loss is  tensor(7507.6064, grad_fn=<AddBackward0>)
# The loss is  tensor(6673.4453, grad_fn=<AddBackward0>)
# The loss is  tensor(6886.5654, grad_fn=<AddBackward0>)
# The loss is  tensor(6915.2217, grad_fn=<AddBackward0>)
# The loss is  tensor(6030.6113, grad_fn=<AddBackward0>)
# The loss is  tensor(6575.6035, grad_fn=<AddBackward0>)
# The loss is  tensor(6548.2734, grad_fn=<AddBackward0>)
# The loss is  tensor(5909.0957, grad_fn=<AddBackward0>)
# The loss is  tensor(5278.1494, grad_fn=<AddBackward0>)
# The loss is  tensor(10559.4238, grad_fn=<AddBackward0>)
# The loss is  tensor(9337.8389, grad_fn=<AddBackward0>)
# The loss is  tensor(9439.8037, grad_fn=<AddBackward0>)
# The loss is  tensor(10456.8691, grad_fn=<AddBackward0>)
# The loss is  tensor(8937.9902, grad_fn=<AddBackward0>)
# The loss is  tensor(9291.3516, grad_fn=<AddBackward0>)
# The loss is  tensor(9389.5752, grad_fn=<AddBackward0>)
# The loss is  tensor(8154.1680, grad_fn=<AddBackward0>)
# The loss is  tensor(9427.0488, grad_fn=<AddBackward0>)
# The loss is  tensor(9089.4912, grad_fn=<AddBackward0>)
# The loss is  tensor(9049.1113, grad_fn=<AddBackward0>)
# The loss is  tensor(8805.6807, grad_fn=<AddBackward0>)
# The loss is  tensor(8925.6201, grad_fn=<AddBackward0>)
# The loss is  tensor(9182.6592, grad_fn=<AddBackward0>)
# The loss is  tensor(9767.4150, grad_fn=<AddBackward0>)
# The loss is  tensor(9574.9922, grad_fn=<AddBackward0>)
# The loss is  tensor(9926.0410, grad_fn=<AddBackward0>)
# The loss is  tensor(9415.4199, grad_fn=<AddBackward0>)
# The loss is  tensor(9711.7598, grad_fn=<AddBackward0>)
# The loss is  tensor(9458.4336, grad_fn=<AddBackward0>)
# The loss is  tensor(7318.5513, grad_fn=<AddBackward0>)
# The loss is  tensor(6821.0527, grad_fn=<AddBackward0>)
# The loss is  tensor(7551.9941, grad_fn=<AddBackward0>)
# The loss is  tensor(6794.1733, grad_fn=<AddBackward0>)
# The loss is  tensor(6790.8115, grad_fn=<AddBackward0>)
# The loss is  tensor(7489.3599, grad_fn=<AddBackward0>)
# The loss is  tensor(6517.5205, grad_fn=<AddBackward0>)
# The loss is  tensor(7149.1104, grad_fn=<AddBackward0>)
# The loss is  tensor(6586.5332, grad_fn=<AddBackward0>)
# The loss is  tensor(6505.5049, grad_fn=<AddBackward0>)
# The loss is  tensor(7651.0239, grad_fn=<AddBackward0>)
# The loss is  tensor(6896.3813, grad_fn=<AddBackward0>)
# The loss is  tensor(7818.0015, grad_fn=<AddBackward0>)
# The loss is  tensor(6636.1602, grad_fn=<AddBackward0>)
# The loss is  tensor(6653.8501, grad_fn=<AddBackward0>)
# The loss is  tensor(6444.3691, grad_fn=<AddBackward0>)
# The loss is  tensor(6358.0449, grad_fn=<AddBackward0>)
# The loss is  tensor(6377.6001, grad_fn=<AddBackward0>)
# The loss is  tensor(6096.3960, grad_fn=<AddBackward0>)
# The loss is  tensor(6297.9912, grad_fn=<AddBackward0>)
# The loss is  tensor(7695.3984, grad_fn=<AddBackward0>)
# The loss is  tensor(8292.9453, grad_fn=<AddBackward0>)
# The loss is  tensor(7854.0093, grad_fn=<AddBackward0>)
# The loss is  tensor(7388.2588, grad_fn=<AddBackward0>)
# The loss is  tensor(7468.9731, grad_fn=<AddBackward0>)
# The loss is  tensor(7549.9634, grad_fn=<AddBackward0>)
# The loss is  tensor(7114.8628, grad_fn=<AddBackward0>)
# The loss is  tensor(7057.9580, grad_fn=<AddBackward0>)
# The loss is  tensor(6757.9082, grad_fn=<AddBackward0>)
# The loss is  tensor(6936.3999, grad_fn=<AddBackward0>)
# The loss is  tensor(5350.5342, grad_fn=<AddBackward0>)
# The loss is  tensor(5817.9639, grad_fn=<AddBackward0>)
# The loss is  tensor(5892.7598, grad_fn=<AddBackward0>)
# The loss is  tensor(5145.4736, grad_fn=<AddBackward0>)
# The loss is  tensor(6003.0786, grad_fn=<AddBackward0>)
# The loss is  tensor(4978.7305, grad_fn=<AddBackward0>)
# The loss is  tensor(4878.9771, grad_fn=<AddBackward0>)
# The loss is  tensor(4940.5005, grad_fn=<AddBackward0>)
# The loss is  tensor(5706.6738, grad_fn=<AddBackward0>)
# The loss is  tensor(4875.0269, grad_fn=<AddBackward0>)
# The loss is  tensor(5013.1670, grad_fn=<AddBackward0>)
# The loss is  tensor(5022.2041, grad_fn=<AddBackward0>)
# The loss is  tensor(4711.4839, grad_fn=<AddBackward0>)
# The loss is  tensor(5078.3833, grad_fn=<AddBackward0>)
# The loss is  tensor(4943.0493, grad_fn=<AddBackward0>)
# The loss is  tensor(4627.2803, grad_fn=<AddBackward0>)
# The loss is  tensor(4723.2207, grad_fn=<AddBackward0>)
# The loss is  tensor(4659.1187, grad_fn=<AddBackward0>)
# The loss is  tensor(4963.0161, grad_fn=<AddBackward0>)
# The loss is  tensor(4276.3291, grad_fn=<AddBackward0>)
# The loss is  tensor(8345.0957, grad_fn=<AddBackward0>)
# The loss is  tensor(9227.9092, grad_fn=<AddBackward0>)
# The loss is  tensor(8538.5371, grad_fn=<AddBackward0>)
# The loss is  tensor(9208.6484, grad_fn=<AddBackward0>)
# The loss is  tensor(8638.5547, grad_fn=<AddBackward0>)
# The loss is  tensor(9162.8057, grad_fn=<AddBackward0>)
# The loss is  tensor(8766.5205, grad_fn=<AddBackward0>)
# The loss is  tensor(7854.9165, grad_fn=<AddBackward0>)
# The loss is  tensor(6822.9604, grad_fn=<AddBackward0>)
# The loss is  tensor(8187.2153, grad_fn=<AddBackward0>)
# The loss is  tensor(7986.4858, grad_fn=<AddBackward0>)
# The loss is  tensor(8024.2021, grad_fn=<AddBackward0>)
# The loss is  tensor(7599.1533, grad_fn=<AddBackward0>)
# The loss is  tensor(7913.9492, grad_fn=<AddBackward0>)
# The loss is  tensor(8852.0547, grad_fn=<AddBackward0>)
# The loss is  tensor(8819.8145, grad_fn=<AddBackward0>)
# The loss is  tensor(8842.2783, grad_fn=<AddBackward0>)
# The loss is  tensor(8481.4062, grad_fn=<AddBackward0>)
# The loss is  tensor(7949.9961, grad_fn=<AddBackward0>)
# The loss is  tensor(7788.2324, grad_fn=<AddBackward0>)
# The loss is  tensor(7952.4434, grad_fn=<AddBackward0>)
# The loss is  tensor(7318.7407, grad_fn=<AddBackward0>)
# The loss is  tensor(8813.4746, grad_fn=<AddBackward0>)
# The loss is  tensor(8795.0195, grad_fn=<AddBackward0>)
# The loss is  tensor(8397.0068, grad_fn=<AddBackward0>)
# The loss is  tensor(7790.5107, grad_fn=<AddBackward0>)
# The loss is  tensor(8072.3594, grad_fn=<AddBackward0>)
# The loss is  tensor(7978.6650, grad_fn=<AddBackward0>)
# The loss is  tensor(6743.2510, grad_fn=<AddBackward0>)
# The loss is  tensor(6334.7637, grad_fn=<AddBackward0>)
# The loss is  tensor(6280.4902, grad_fn=<AddBackward0>)
# The loss is  tensor(6639.1191, grad_fn=<AddBackward0>)
# The loss is  tensor(6727.6748, grad_fn=<AddBackward0>)
# The loss is  tensor(6417.0527, grad_fn=<AddBackward0>)
# The loss is  tensor(6434.9077, grad_fn=<AddBackward0>)
# The loss is  tensor(5811.5776, grad_fn=<AddBackward0>)
# The loss is  tensor(5908.5566, grad_fn=<AddBackward0>)
# The loss is  tensor(5623.6504, grad_fn=<AddBackward0>)
# The loss is  tensor(9769.3096, grad_fn=<AddBackward0>)
# The loss is  tensor(8983.5361, grad_fn=<AddBackward0>)
# The loss is  tensor(9361.3408, grad_fn=<AddBackward0>)
# The loss is  tensor(9360.8184, grad_fn=<AddBackward0>)
# The loss is  tensor(8591.8535, grad_fn=<AddBackward0>)
# The loss is  tensor(8551.0068, grad_fn=<AddBackward0>)
# The loss is  tensor(9176.8223, grad_fn=<AddBackward0>)
# The loss is  tensor(8298.7578, grad_fn=<AddBackward0>)
# The loss is  tensor(8946.7129, grad_fn=<AddBackward0>)
# The loss is  tensor(8897.4688, grad_fn=<AddBackward0>)
# The loss is  tensor(8718.3398, grad_fn=<AddBackward0>)
# The loss is  tensor(8786.4971, grad_fn=<AddBackward0>)
# The loss is  tensor(8794.2656, grad_fn=<AddBackward0>)
# The loss is  tensor(8966.8975, grad_fn=<AddBackward0>)
# The loss is  tensor(9528.9883, grad_fn=<AddBackward0>)
# The loss is  tensor(9502.5049, grad_fn=<AddBackward0>)
# The loss is  tensor(9522.3594, grad_fn=<AddBackward0>)
# The loss is  tensor(9238.2979, grad_fn=<AddBackward0>)
# The loss is  tensor(9674.5859, grad_fn=<AddBackward0>)
# The loss is  tensor(9419.4209, grad_fn=<AddBackward0>)
# The loss is  tensor(6563.0107, grad_fn=<AddBackward0>)
# The loss is  tensor(6695.7764, grad_fn=<AddBackward0>)
# The loss is  tensor(6619.8408, grad_fn=<AddBackward0>)
# The loss is  tensor(7959.0942, grad_fn=<AddBackward0>)
# The loss is  tensor(6538.8262, grad_fn=<AddBackward0>)
# The loss is  tensor(6350.0449, grad_fn=<AddBackward0>)
# The loss is  tensor(6513.3906, grad_fn=<AddBackward0>)
# The loss is  tensor(7030.9287, grad_fn=<AddBackward0>)
# The loss is  tensor(6257.0439, grad_fn=<AddBackward0>)
# The loss is  tensor(6523.5869, grad_fn=<AddBackward0>)
# The loss is  tensor(6816.0723, grad_fn=<AddBackward0>)
# The loss is  tensor(7045.0664, grad_fn=<AddBackward0>)
# The loss is  tensor(6799.0449, grad_fn=<AddBackward0>)
# The loss is  tensor(7749.6846, grad_fn=<AddBackward0>)
# The loss is  tensor(7170.8516, grad_fn=<AddBackward0>)
# The loss is  tensor(6568.3237, grad_fn=<AddBackward0>)
# The loss is  tensor(7486.2319, grad_fn=<AddBackward0>)
# The loss is  tensor(6333.0264, grad_fn=<AddBackward0>)
# The loss is  tensor(6228.6963, grad_fn=<AddBackward0>)
# The loss is  tensor(6176.8501, grad_fn=<AddBackward0>)
# The loss is  tensor(8022.8545, grad_fn=<AddBackward0>)
# The loss is  tensor(7444.1318, grad_fn=<AddBackward0>)
# The loss is  tensor(7513.1309, grad_fn=<AddBackward0>)
# The loss is  tensor(7236.0972, grad_fn=<AddBackward0>)
# The loss is  tensor(7194.0327, grad_fn=<AddBackward0>)
# The loss is  tensor(7423.3315, grad_fn=<AddBackward0>)
# The loss is  tensor(6966.7393, grad_fn=<AddBackward0>)
# The loss is  tensor(7129.3481, grad_fn=<AddBackward0>)
# The loss is  tensor(6738.0581, grad_fn=<AddBackward0>)
# The loss is  tensor(7003.4365, grad_fn=<AddBackward0>)
# The loss is  tensor(5252.9404, grad_fn=<AddBackward0>)
# The loss is  tensor(5476.0137, grad_fn=<AddBackward0>)
# The loss is  tensor(5642.0889, grad_fn=<AddBackward0>)
# The loss is  tensor(5281.5332, grad_fn=<AddBackward0>)
# The loss is  tensor(5334.0469, grad_fn=<AddBackward0>)
# The loss is  tensor(5984.0283, grad_fn=<AddBackward0>)
# The loss is  tensor(4916.6055, grad_fn=<AddBackward0>)
# The loss is  tensor(4914.3652, grad_fn=<AddBackward0>)
# The loss is  tensor(4822.6748, grad_fn=<AddBackward0>)
# The loss is  tensor(4888.3491, grad_fn=<AddBackward0>)
# The loss is  tensor(4732.3467, grad_fn=<AddBackward0>)
# The loss is  tensor(4592.4976, grad_fn=<AddBackward0>)
# The loss is  tensor(4489.9360, grad_fn=<AddBackward0>)
# The loss is  tensor(4664.7227, grad_fn=<AddBackward0>)
# The loss is  tensor(4651.0093, grad_fn=<AddBackward0>)
# The loss is  tensor(4324.9478, grad_fn=<AddBackward0>)
# The loss is  tensor(4566.8872, grad_fn=<AddBackward0>)
# The loss is  tensor(4276.5444, grad_fn=<AddBackward0>)
# The loss is  tensor(4747.1157, grad_fn=<AddBackward0>)
# The loss is  tensor(4336.3140, grad_fn=<AddBackward0>)
# The loss is  tensor(7646.1279, grad_fn=<AddBackward0>)
# The loss is  tensor(9038.5898, grad_fn=<AddBackward0>)
# The loss is  tensor(8335.6211, grad_fn=<AddBackward0>)
# The loss is  tensor(9118.7578, grad_fn=<AddBackward0>)
# The loss is  tensor(8912.2832, grad_fn=<AddBackward0>)
# The loss is  tensor(9116.9834, grad_fn=<AddBackward0>)
# The loss is  tensor(7981.9517, grad_fn=<AddBackward0>)
# The loss is  tensor(7470.2451, grad_fn=<AddBackward0>)
# The loss is  tensor(6243.1685, grad_fn=<AddBackward0>)
# The loss is  tensor(7593.2119, grad_fn=<AddBackward0>)
# The loss is  tensor(7680.9199, grad_fn=<AddBackward0>)
# The loss is  tensor(7665.6196, grad_fn=<AddBackward0>)
# The loss is  tensor(7281.0737, grad_fn=<AddBackward0>)
# The loss is  tensor(7339.6992, grad_fn=<AddBackward0>)
# The loss is  tensor(7752.6196, grad_fn=<AddBackward0>)
# The loss is  tensor(8441.2002, grad_fn=<AddBackward0>)
# The loss is  tensor(8508.5576, grad_fn=<AddBackward0>)
# The loss is  tensor(8111.6191, grad_fn=<AddBackward0>)
# The loss is  tensor(7884.1060, grad_fn=<AddBackward0>)
# The loss is  tensor(7396.0342, grad_fn=<AddBackward0>)
# The loss is  tensor(7791.9028, grad_fn=<AddBackward0>)
# The loss is  tensor(7453.1235, grad_fn=<AddBackward0>)
# The loss is  tensor(8364.4023, grad_fn=<AddBackward0>)
# The loss is  tensor(8442.8086, grad_fn=<AddBackward0>)
# The loss is  tensor(8098.6592, grad_fn=<AddBackward0>)
# The loss is  tensor(8131.2178, grad_fn=<AddBackward0>)
# The loss is  tensor(7723.9688, grad_fn=<AddBackward0>)
# The loss is  tensor(7815.5010, grad_fn=<AddBackward0>)
# The loss is  tensor(7120.8491, grad_fn=<AddBackward0>)
# The loss is  tensor(6869.9902, grad_fn=<AddBackward0>)
# The loss is  tensor(6708.8740, grad_fn=<AddBackward0>)
# The loss is  tensor(6347.0479, grad_fn=<AddBackward0>)
# The loss is  tensor(6005.2686, grad_fn=<AddBackward0>)
# The loss is  tensor(6323.1782, grad_fn=<AddBackward0>)
# The loss is  tensor(6010.2471, grad_fn=<AddBackward0>)
# The loss is  tensor(5796.4600, grad_fn=<AddBackward0>)
# The loss is  tensor(5699.8496, grad_fn=<AddBackward0>)
# The loss is  tensor(4858.5977, grad_fn=<AddBackward0>)
# The loss is  tensor(9753.8799, grad_fn=<AddBackward0>)
# The loss is  tensor(9183.7969, grad_fn=<AddBackward0>)
# The loss is  tensor(9015.0820, grad_fn=<AddBackward0>)
# The loss is  tensor(9509.8633, grad_fn=<AddBackward0>)
# The loss is  tensor(8819.2969, grad_fn=<AddBackward0>)
# The loss is  tensor(8614.2246, grad_fn=<AddBackward0>)
# The loss is  tensor(9441.3184, grad_fn=<AddBackward0>)
# The loss is  tensor(7558.9805, grad_fn=<AddBackward0>)
# The loss is  tensor(8315.0410, grad_fn=<AddBackward0>)
# The loss is  tensor(8703.5088, grad_fn=<AddBackward0>)
# The loss is  tensor(8667.1436, grad_fn=<AddBackward0>)
# The loss is  tensor(8563.3379, grad_fn=<AddBackward0>)
# The loss is  tensor(8592.2842, grad_fn=<AddBackward0>)
# The loss is  tensor(8793.5508, grad_fn=<AddBackward0>)
# The loss is  tensor(9371.0547, grad_fn=<AddBackward0>)
# The loss is  tensor(9263.1436, grad_fn=<AddBackward0>)
# The loss is  tensor(9571.1582, grad_fn=<AddBackward0>)
# The loss is  tensor(9157.9893, grad_fn=<AddBackward0>)
# The loss is  tensor(9347.9746, grad_fn=<AddBackward0>)
# The loss is  tensor(9274.3721, grad_fn=<AddBackward0>)
# The loss is  tensor(6547.8687, grad_fn=<AddBackward0>)
# The loss is  tensor(6248.6094, grad_fn=<AddBackward0>)
# The loss is  tensor(6556.0732, grad_fn=<AddBackward0>)
# The loss is  tensor(6717.9727, grad_fn=<AddBackward0>)
# The loss is  tensor(6591.8081, grad_fn=<AddBackward0>)
# The loss is  tensor(7299.3906, grad_fn=<AddBackward0>)
# The loss is  tensor(7778.9644, grad_fn=<AddBackward0>)
# The loss is  tensor(6108.0547, grad_fn=<AddBackward0>)
# The loss is  tensor(6185.2598, grad_fn=<AddBackward0>)
# The loss is  tensor(6348.8218, grad_fn=<AddBackward0>)
# The loss is  tensor(6910.9707, grad_fn=<AddBackward0>)
# The loss is  tensor(6776.4561, grad_fn=<AddBackward0>)
# The loss is  tensor(6654.1831, grad_fn=<AddBackward0>)
# The loss is  tensor(6568.6587, grad_fn=<AddBackward0>)
# The loss is  tensor(7841.9395, grad_fn=<AddBackward0>)
# The loss is  tensor(6481.1328, grad_fn=<AddBackward0>)
# The loss is  tensor(6137.7568, grad_fn=<AddBackward0>)
# The loss is  tensor(7509.4731, grad_fn=<AddBackward0>)
# The loss is  tensor(6154.0034, grad_fn=<AddBackward0>)
# The loss is  tensor(7248.1802, grad_fn=<AddBackward0>)
# The loss is  tensor(8448.3154, grad_fn=<AddBackward0>)
# The loss is  tensor(8369.6465, grad_fn=<AddBackward0>)
# The loss is  tensor(7504.5283, grad_fn=<AddBackward0>)
# The loss is  tensor(7299.7637, grad_fn=<AddBackward0>)
# The loss is  tensor(7100.2891, grad_fn=<AddBackward0>)
# The loss is  tensor(8179.6201, grad_fn=<AddBackward0>)
# The loss is  tensor(6970.3066, grad_fn=<AddBackward0>)
# The loss is  tensor(7014.7188, grad_fn=<AddBackward0>)
# The loss is  tensor(6763.1519, grad_fn=<AddBackward0>)
# The loss is  tensor(7139.4648, grad_fn=<AddBackward0>)
# The loss is  tensor(5296.2769, grad_fn=<AddBackward0>)
# The loss is  tensor(5205.4868, grad_fn=<AddBackward0>)
# The loss is  tensor(5174.4946, grad_fn=<AddBackward0>)
# The loss is  tensor(5318.9062, grad_fn=<AddBackward0>)
# The loss is  tensor(4967.9297, grad_fn=<AddBackward0>)
# The loss is  tensor(4933.8442, grad_fn=<AddBackward0>)
# The loss is  tensor(5581.1943, grad_fn=<AddBackward0>)
# The loss is  tensor(4922.2339, grad_fn=<AddBackward0>)
# The loss is  tensor(4809.6699, grad_fn=<AddBackward0>)
# The loss is  tensor(4801.3569, grad_fn=<AddBackward0>)
# The loss is  tensor(4479.4521, grad_fn=<AddBackward0>)
# The loss is  tensor(4462.4370, grad_fn=<AddBackward0>)
# The loss is  tensor(4147.5259, grad_fn=<AddBackward0>)
# The loss is  tensor(4401.7998, grad_fn=<AddBackward0>)
# The loss is  tensor(4268.1372, grad_fn=<AddBackward0>)
# The loss is  tensor(3998.2261, grad_fn=<AddBackward0>)
# The loss is  tensor(4498.0396, grad_fn=<AddBackward0>)
# The loss is  tensor(4018.0371, grad_fn=<AddBackward0>)
# The loss is  tensor(4400.1206, grad_fn=<AddBackward0>)
# The loss is  tensor(3815.0942, grad_fn=<AddBackward0>)
# The loss is  tensor(7390.2363, grad_fn=<AddBackward0>)
# The loss is  tensor(8507.0234, grad_fn=<AddBackward0>)
# The loss is  tensor(7520.4951, grad_fn=<AddBackward0>)
# The loss is  tensor(8728.8018, grad_fn=<AddBackward0>)
# The loss is  tensor(8172.5142, grad_fn=<AddBackward0>)
# The loss is  tensor(8773.0820, grad_fn=<AddBackward0>)
# The loss is  tensor(8231.7285, grad_fn=<AddBackward0>)
# The loss is  tensor(7247.6118, grad_fn=<AddBackward0>)
# The loss is  tensor(6541.0361, grad_fn=<AddBackward0>)
# The loss is  tensor(6548.5825, grad_fn=<AddBackward0>)
# The loss is  tensor(6872.8481, grad_fn=<AddBackward0>)
# The loss is  tensor(6701.8301, grad_fn=<AddBackward0>)
# The loss is  tensor(6814.4951, grad_fn=<AddBackward0>)
# The loss is  tensor(7286.6260, grad_fn=<AddBackward0>)
# The loss is  tensor(7474.5405, grad_fn=<AddBackward0>)
# The loss is  tensor(7602.9683, grad_fn=<AddBackward0>)
# The loss is  tensor(7741.0283, grad_fn=<AddBackward0>)
# The loss is  tensor(7715.5308, grad_fn=<AddBackward0>)
# The loss is  tensor(7362.6753, grad_fn=<AddBackward0>)
# The loss is  tensor(6916.1694, grad_fn=<AddBackward0>)
# The loss is  tensor(7013.4961, grad_fn=<AddBackward0>)
# The loss is  tensor(6955.2764, grad_fn=<AddBackward0>)
# The loss is  tensor(7963.3169, grad_fn=<AddBackward0>)
# The loss is  tensor(7669.2988, grad_fn=<AddBackward0>)
# The loss is  tensor(7724.6025, grad_fn=<AddBackward0>)
# The loss is  tensor(7651.1470, grad_fn=<AddBackward0>)
# The loss is  tensor(6857.6479, grad_fn=<AddBackward0>)
# The loss is  tensor(6705.7500, grad_fn=<AddBackward0>)
# The loss is  tensor(6424.0098, grad_fn=<AddBackward0>)
# The loss is  tensor(6385.2036, grad_fn=<AddBackward0>)
# The loss is  tensor(6419.4307, grad_fn=<AddBackward0>)
# The loss is  tensor(6205.4272, grad_fn=<AddBackward0>)
# The loss is  tensor(5645.5303, grad_fn=<AddBackward0>)
# The loss is  tensor(5539.2705, grad_fn=<AddBackward0>)
# The loss is  tensor(5213.3359, grad_fn=<AddBackward0>)
# The loss is  tensor(5086.9004, grad_fn=<AddBackward0>)
# The loss is  tensor(5388.9146, grad_fn=<AddBackward0>)
# The loss is  tensor(5291.9004, grad_fn=<AddBackward0>)
# The loss is  tensor(9462.0781, grad_fn=<AddBackward0>)
# The loss is  tensor(8832.0449, grad_fn=<AddBackward0>)
# The loss is  tensor(8646.3809, grad_fn=<AddBackward0>)
# The loss is  tensor(9346.6328, grad_fn=<AddBackward0>)
# The loss is  tensor(8715.2832, grad_fn=<AddBackward0>)
# The loss is  tensor(7984.3218, grad_fn=<AddBackward0>)
# The loss is  tensor(8562.4805, grad_fn=<AddBackward0>)
# The loss is  tensor(7959.6875, grad_fn=<AddBackward0>)
# The loss is  tensor(8533.2852, grad_fn=<AddBackward0>)
# The loss is  tensor(8500.0176, grad_fn=<AddBackward0>)
# The loss is  tensor(8523.8408, grad_fn=<AddBackward0>)
# The loss is  tensor(8413.8467, grad_fn=<AddBackward0>)
# The loss is  tensor(8432.9004, grad_fn=<AddBackward0>)
# The loss is  tensor(8772.0391, grad_fn=<AddBackward0>)
# The loss is  tensor(9260.8350, grad_fn=<AddBackward0>)
# The loss is  tensor(9193.0566, grad_fn=<AddBackward0>)
# The loss is  tensor(9280.3965, grad_fn=<AddBackward0>)
# The loss is  tensor(8939.7139, grad_fn=<AddBackward0>)
# The loss is  tensor(9140.4902, grad_fn=<AddBackward0>)
# The loss is  tensor(8938.1914, grad_fn=<AddBackward0>)
# The loss is  tensor(6247.8311, grad_fn=<AddBackward0>)
# The loss is  tensor(6474.1348, grad_fn=<AddBackward0>)
# The loss is  tensor(6064.1787, grad_fn=<AddBackward0>)
# The loss is  tensor(6477.9351, grad_fn=<AddBackward0>)
# The loss is  tensor(6274.3970, grad_fn=<AddBackward0>)
# The loss is  tensor(6157.5869, grad_fn=<AddBackward0>)
# The loss is  tensor(6376.1582, grad_fn=<AddBackward0>)
# The loss is  tensor(7459.4658, grad_fn=<AddBackward0>)
# The loss is  tensor(6011.4688, grad_fn=<AddBackward0>)
# The loss is  tensor(7468.4395, grad_fn=<AddBackward0>)
# The loss is  tensor(6588.0957, grad_fn=<AddBackward0>)
# The loss is  tensor(6528.2627, grad_fn=<AddBackward0>)
# The loss is  tensor(6832.4131, grad_fn=<AddBackward0>)
# The loss is  tensor(6493.4844, grad_fn=<AddBackward0>)
# The loss is  tensor(7314.0503, grad_fn=<AddBackward0>)
# The loss is  tensor(6301.9653, grad_fn=<AddBackward0>)
# The loss is  tensor(6193.8711, grad_fn=<AddBackward0>)
# The loss is  tensor(6166.4717, grad_fn=<AddBackward0>)
# The loss is  tensor(6421.6997, grad_fn=<AddBackward0>)
# The loss is  tensor(5935.9619, grad_fn=<AddBackward0>)
# The loss is  tensor(7474.1709, grad_fn=<AddBackward0>)
# The loss is  tensor(7234.1484, grad_fn=<AddBackward0>)
# The loss is  tensor(8751.0146, grad_fn=<AddBackward0>)
# The loss is  tensor(7036.2617, grad_fn=<AddBackward0>)
# The loss is  tensor(7514.3730, grad_fn=<AddBackward0>)
# The loss is  tensor(8417.1777, grad_fn=<AddBackward0>)
# The loss is  tensor(6726.6777, grad_fn=<AddBackward0>)
# The loss is  tensor(6907.5840, grad_fn=<AddBackward0>)
# The loss is  tensor(6654.4834, grad_fn=<AddBackward0>)
# The loss is  tensor(6903.9722, grad_fn=<AddBackward0>)
# The loss is  tensor(5662.8232, grad_fn=<AddBackward0>)
# The loss is  tensor(6288.6997, grad_fn=<AddBackward0>)
# The loss is  tensor(4915.5737, grad_fn=<AddBackward0>)
# The loss is  tensor(5297.9106, grad_fn=<AddBackward0>)
# The loss is  tensor(5715.1978, grad_fn=<AddBackward0>)
# The loss is  tensor(4878.9175, grad_fn=<AddBackward0>)
# The loss is  tensor(5158.9873, grad_fn=<AddBackward0>)
# The loss is  tensor(5326.2002, grad_fn=<AddBackward0>)
# The loss is  tensor(4675.9414, grad_fn=<AddBackward0>)
# The loss is  tensor(4795.4214, grad_fn=<AddBackward0>)
# The loss is  tensor(4203.0176, grad_fn=<AddBackward0>)
# The loss is  tensor(4253.5479, grad_fn=<AddBackward0>)
# The loss is  tensor(3815.9749, grad_fn=<AddBackward0>)
# The loss is  tensor(4216.4619, grad_fn=<AddBackward0>)
# The loss is  tensor(4125.2939, grad_fn=<AddBackward0>)
# The loss is  tensor(3915.4563, grad_fn=<AddBackward0>)
# The loss is  tensor(4234.0879, grad_fn=<AddBackward0>)
# The loss is  tensor(3835.0239, grad_fn=<AddBackward0>)
# The loss is  tensor(4043.6968, grad_fn=<AddBackward0>)
# The loss is  tensor(3748.4736, grad_fn=<AddBackward0>)
# The loss is  tensor(7293.1313, grad_fn=<AddBackward0>)
# The loss is  tensor(8308.6992, grad_fn=<AddBackward0>)
# The loss is  tensor(7633.3149, grad_fn=<AddBackward0>)
# The loss is  tensor(7932.5620, grad_fn=<AddBackward0>)
# The loss is  tensor(8521.4189, grad_fn=<AddBackward0>)
# The loss is  tensor(8364.7393, grad_fn=<AddBackward0>)
# The loss is  tensor(7793.2144, grad_fn=<AddBackward0>)
# The loss is  tensor(7023.2744, grad_fn=<AddBackward0>)
# The loss is  tensor(5933.9097, grad_fn=<AddBackward0>)
# The loss is  tensor(7199.1973, grad_fn=<AddBackward0>)
# The loss is  tensor(7048.0508, grad_fn=<AddBackward0>)
# The loss is  tensor(6174.6992, grad_fn=<AddBackward0>)
# The loss is  tensor(6427.2764, grad_fn=<AddBackward0>)
# The loss is  tensor(7036.0503, grad_fn=<AddBackward0>)
# The loss is  tensor(7084.2061, grad_fn=<AddBackward0>)
# The loss is  tensor(7726.1763, grad_fn=<AddBackward0>)
# The loss is  tensor(7857.7681, grad_fn=<AddBackward0>)
# The loss is  tensor(6645.5303, grad_fn=<AddBackward0>)
# The loss is  tensor(6354.4155, grad_fn=<AddBackward0>)
# The loss is  tensor(6941.3687, grad_fn=<AddBackward0>)
# The loss is  tensor(6749.4814, grad_fn=<AddBackward0>)
# The loss is  tensor(6678.0898, grad_fn=<AddBackward0>)
# The loss is  tensor(7799.2500, grad_fn=<AddBackward0>)
# The loss is  tensor(7126.0518, grad_fn=<AddBackward0>)
# The loss is  tensor(7113.0166, grad_fn=<AddBackward0>)
# The loss is  tensor(7444.5938, grad_fn=<AddBackward0>)
# The loss is  tensor(7119.1152, grad_fn=<AddBackward0>)
# The loss is  tensor(6412.7251, grad_fn=<AddBackward0>)
# The loss is  tensor(5746.9644, grad_fn=<AddBackward0>)
# The loss is  tensor(5897.5239, grad_fn=<AddBackward0>)
# The loss is  tensor(6078.9653, grad_fn=<AddBackward0>)
# The loss is  tensor(5162.1143, grad_fn=<AddBackward0>)
# The loss is  tensor(5837.3447, grad_fn=<AddBackward0>)
# The loss is  tensor(5714.2539, grad_fn=<AddBackward0>)
# The loss is  tensor(5506.0215, grad_fn=<AddBackward0>)
# The loss is  tensor(4946.1250, grad_fn=<AddBackward0>)
# The loss is  tensor(5029.4321, grad_fn=<AddBackward0>)
# The loss is  tensor(5139.8477, grad_fn=<AddBackward0>)
# The loss is  tensor(9084.9238, grad_fn=<AddBackward0>)
# The loss is  tensor(8093.7383, grad_fn=<AddBackward0>)
# The loss is  tensor(8480.4893, grad_fn=<AddBackward0>)
# The loss is  tensor(8521.3535, grad_fn=<AddBackward0>)
# The loss is  tensor(8477.4375, grad_fn=<AddBackward0>)
# The loss is  tensor(8283.0381, grad_fn=<AddBackward0>)
# The loss is  tensor(8877.8486, grad_fn=<AddBackward0>)
# The loss is  tensor(7641.3384, grad_fn=<AddBackward0>)
# The loss is  tensor(8296.8906, grad_fn=<AddBackward0>)
# The loss is  tensor(7764.0410, grad_fn=<AddBackward0>)
# The loss is  tensor(8438.4805, grad_fn=<AddBackward0>)
# The loss is  tensor(8299.5371, grad_fn=<AddBackward0>)
# The loss is  tensor(8205.3955, grad_fn=<AddBackward0>)
# The loss is  tensor(8362.8594, grad_fn=<AddBackward0>)
# The loss is  tensor(9058.3164, grad_fn=<AddBackward0>)
# The loss is  tensor(8830.5664, grad_fn=<AddBackward0>)
# The loss is  tensor(9099.6650, grad_fn=<AddBackward0>)
# The loss is  tensor(8642.6045, grad_fn=<AddBackward0>)
# The loss is  tensor(8892.8174, grad_fn=<AddBackward0>)
# The loss is  tensor(8675.7168, grad_fn=<AddBackward0>)
# The loss is  tensor(6268.4238, grad_fn=<AddBackward0>)
# The loss is  tensor(6018.2910, grad_fn=<AddBackward0>)
# The loss is  tensor(5868.7373, grad_fn=<AddBackward0>)
# The loss is  tensor(7485.3193, grad_fn=<AddBackward0>)
# The loss is  tensor(5953.3164, grad_fn=<AddBackward0>)
# The loss is  tensor(5974.7686, grad_fn=<AddBackward0>)
# The loss is  tensor(5939.1680, grad_fn=<AddBackward0>)
# The loss is  tensor(5759.6089, grad_fn=<AddBackward0>)
# The loss is  tensor(5816.2139, grad_fn=<AddBackward0>)
# The loss is  tensor(5848.3145, grad_fn=<AddBackward0>)
# The loss is  tensor(7189.4609, grad_fn=<AddBackward0>)
# The loss is  tensor(6450.7578, grad_fn=<AddBackward0>)
# The loss is  tensor(6639.3984, grad_fn=<AddBackward0>)
# The loss is  tensor(6403.8594, grad_fn=<AddBackward0>)
# The loss is  tensor(6649.9873, grad_fn=<AddBackward0>)
# The loss is  tensor(6238.5786, grad_fn=<AddBackward0>)
# The loss is  tensor(6733.7256, grad_fn=<AddBackward0>)
# The loss is  tensor(6193.1631, grad_fn=<AddBackward0>)
# The loss is  tensor(5626.2617, grad_fn=<AddBackward0>)
# The loss is  tensor(6599.1348, grad_fn=<AddBackward0>)
# The loss is  tensor(7069.8896, grad_fn=<AddBackward0>)
# The loss is  tensor(7616.1143, grad_fn=<AddBackward0>)
# The loss is  tensor(7149.6294, grad_fn=<AddBackward0>)
# The loss is  tensor(6856.3403, grad_fn=<AddBackward0>)
# The loss is  tensor(6916.7969, grad_fn=<AddBackward0>)
# The loss is  tensor(6904.7109, grad_fn=<AddBackward0>)
# The loss is  tensor(7803.3486, grad_fn=<AddBackward0>)
# The loss is  tensor(6654.8833, grad_fn=<AddBackward0>)
# The loss is  tensor(6583.7041, grad_fn=<AddBackward0>)
# The loss is  tensor(6704.4336, grad_fn=<AddBackward0>)
# The loss is  tensor(4946.0078, grad_fn=<AddBackward0>)
# The loss is  tensor(4779.3530, grad_fn=<AddBackward0>)
# The loss is  tensor(4926.6328, grad_fn=<AddBackward0>)
# The loss is  tensor(4963.5088, grad_fn=<AddBackward0>)
# The loss is  tensor(4710.7803, grad_fn=<AddBackward0>)
# The loss is  tensor(4859.3691, grad_fn=<AddBackward0>)
# The loss is  tensor(4816.8301, grad_fn=<AddBackward0>)
# The loss is  tensor(4610.4585, grad_fn=<AddBackward0>)
# The loss is  tensor(4810.7207, grad_fn=<AddBackward0>)
# The loss is  tensor(4603.9316, grad_fn=<AddBackward0>)
# The loss is  tensor(4159., grad_fn=<AddBackward0>)
# The loss is  tensor(3981.3081, grad_fn=<AddBackward0>)
# The loss is  tensor(3623.5393, grad_fn=<AddBackward0>)
# The loss is  tensor(3984.3538, grad_fn=<AddBackward0>)
# The loss is  tensor(3758.8875, grad_fn=<AddBackward0>)
# The loss is  tensor(3575.5776, grad_fn=<AddBackward0>)
# The loss is  tensor(4027.7849, grad_fn=<AddBackward0>)
# The loss is  tensor(3557.0168, grad_fn=<AddBackward0>)
# The loss is  tensor(3846.1753, grad_fn=<AddBackward0>)
# The loss is  tensor(3595.5010, grad_fn=<AddBackward0>)
# The loss is  tensor(6963.1519, grad_fn=<AddBackward0>)
# The loss is  tensor(8080.4561, grad_fn=<AddBackward0>)
# The loss is  tensor(6569.9336, grad_fn=<AddBackward0>)
# The loss is  tensor(8247.3604, grad_fn=<AddBackward0>)
# The loss is  tensor(8065.3398, grad_fn=<AddBackward0>)
# The loss is  tensor(7985.7534, grad_fn=<AddBackward0>)
# The loss is  tensor(7320.0024, grad_fn=<AddBackward0>)
# The loss is  tensor(6433.1162, grad_fn=<AddBackward0>)
# The loss is  tensor(5449.1689, grad_fn=<AddBackward0>)
# The loss is  tensor(6048.5718, grad_fn=<AddBackward0>)
# The loss is  tensor(6745.6792, grad_fn=<AddBackward0>)
# The loss is  tensor(6815.0645, grad_fn=<AddBackward0>)
# The loss is  tensor(6141.2012, grad_fn=<AddBackward0>)
# The loss is  tensor(6061.6855, grad_fn=<AddBackward0>)
# The loss is  tensor(7578.1577, grad_fn=<AddBackward0>)
# The loss is  tensor(7488.0405, grad_fn=<AddBackward0>)
# The loss is  tensor(7488.9604, grad_fn=<AddBackward0>)
# The loss is  tensor(7235.7627, grad_fn=<AddBackward0>)
# The loss is  tensor(6796.8965, grad_fn=<AddBackward0>)
# The loss is  tensor(6938.4448, grad_fn=<AddBackward0>)
# The loss is  tensor(6845.6436, grad_fn=<AddBackward0>)
# The loss is  tensor(6437.9429, grad_fn=<AddBackward0>)
# The loss is  tensor(7375.0835, grad_fn=<AddBackward0>)
# The loss is  tensor(6660.5811, grad_fn=<AddBackward0>)
# The loss is  tensor(7307.5205, grad_fn=<AddBackward0>)
# The loss is  tensor(7219.2148, grad_fn=<AddBackward0>)
# The loss is  tensor(6551.8105, grad_fn=<AddBackward0>)
# The loss is  tensor(6516.5771, grad_fn=<AddBackward0>)
# The loss is  tensor(6204.0010, grad_fn=<AddBackward0>)
# The loss is  tensor(6104.6831, grad_fn=<AddBackward0>)
# The loss is  tensor(5447.7295, grad_fn=<AddBackward0>)
# The loss is  tensor(5729.1890, grad_fn=<AddBackward0>)
# The loss is  tensor(5630.2681, grad_fn=<AddBackward0>)
# The loss is  tensor(4781.3506, grad_fn=<AddBackward0>)
# The loss is  tensor(4616.9546, grad_fn=<AddBackward0>)
# The loss is  tensor(5366.5142, grad_fn=<AddBackward0>)
# The loss is  tensor(5139.5908, grad_fn=<AddBackward0>)
# The loss is  tensor(4647.1377, grad_fn=<AddBackward0>)
# The loss is  tensor(8620.9922, grad_fn=<AddBackward0>)
# The loss is  tensor(8565.9688, grad_fn=<AddBackward0>)
# The loss is  tensor(8239.0869, grad_fn=<AddBackward0>)
# The loss is  tensor(9028.3242, grad_fn=<AddBackward0>)
# The loss is  tensor(7504.8154, grad_fn=<AddBackward0>)
# The loss is  tensor(7512.5669, grad_fn=<AddBackward0>)
# The loss is  tensor(8659.7334, grad_fn=<AddBackward0>)
# The loss is  tensor(7527.2646, grad_fn=<AddBackward0>)
# The loss is  tensor(8094.8389, grad_fn=<AddBackward0>)
# The loss is  tensor(7623.1729, grad_fn=<AddBackward0>)
# The loss is  tensor(8137.6978, grad_fn=<AddBackward0>)
# The loss is  tensor(8189.7012, grad_fn=<AddBackward0>)
# The loss is  tensor(7872.7988, grad_fn=<AddBackward0>)
# The loss is  tensor(8216.1982, grad_fn=<AddBackward0>)
# The loss is  tensor(8820.1514, grad_fn=<AddBackward0>)
# The loss is  tensor(8838.4688, grad_fn=<AddBackward0>)
# The loss is  tensor(9018.1699, grad_fn=<AddBackward0>)
# The loss is  tensor(8384.2246, grad_fn=<AddBackward0>)
# The loss is  tensor(8628.2324, grad_fn=<AddBackward0>)
# The loss is  tensor(8469.3770, grad_fn=<AddBackward0>)
# The loss is  tensor(6085.1006, grad_fn=<AddBackward0>)
# The loss is  tensor(6188.7700, grad_fn=<AddBackward0>)
# The loss is  tensor(5695.9844, grad_fn=<AddBackward0>)
# The loss is  tensor(5804.0020, grad_fn=<AddBackward0>)
# The loss is  tensor(5873.0303, grad_fn=<AddBackward0>)
# The loss is  tensor(6073.9150, grad_fn=<AddBackward0>)
# The loss is  tensor(6608.4434, grad_fn=<AddBackward0>)
# The loss is  tensor(5992., grad_fn=<AddBackward0>)
# The loss is  tensor(5691.8643, grad_fn=<AddBackward0>)
# The loss is  tensor(6784.7324, grad_fn=<AddBackward0>)
# The loss is  tensor(7663.7935, grad_fn=<AddBackward0>)
# The loss is  tensor(6315.5347, grad_fn=<AddBackward0>)
# The loss is  tensor(6270.9268, grad_fn=<AddBackward0>)
# The loss is  tensor(5885.1758, grad_fn=<AddBackward0>)
# The loss is  tensor(6248.3667, grad_fn=<AddBackward0>)
# The loss is  tensor(5829.1758, grad_fn=<AddBackward0>)
# The loss is  tensor(5870.2407, grad_fn=<AddBackward0>)
# The loss is  tensor(6678.9561, grad_fn=<AddBackward0>)
# The loss is  tensor(5623.8164, grad_fn=<AddBackward0>)
# The loss is  tensor(5670.0479, grad_fn=<AddBackward0>)
# The loss is  tensor(8340.9893, grad_fn=<AddBackward0>)
# The loss is  tensor(6889.4199, grad_fn=<AddBackward0>)
# The loss is  tensor(7353.3232, grad_fn=<AddBackward0>)
# The loss is  tensor(6762.8359, grad_fn=<AddBackward0>)
# The loss is  tensor(7967.8540, grad_fn=<AddBackward0>)
# The loss is  tensor(7809.9839, grad_fn=<AddBackward0>)
# The loss is  tensor(6596.0142, grad_fn=<AddBackward0>)
# The loss is  tensor(6468.6182, grad_fn=<AddBackward0>)
# The loss is  tensor(7403.5752, grad_fn=<AddBackward0>)
# The loss is  tensor(6488.6836, grad_fn=<AddBackward0>)
# The loss is  tensor(4836.9985, grad_fn=<AddBackward0>)
# The loss is  tensor(4875.0752, grad_fn=<AddBackward0>)
# The loss is  tensor(4780.8203, grad_fn=<AddBackward0>)
# The loss is  tensor(4666.8940, grad_fn=<AddBackward0>)
# The loss is  tensor(5375.9282, grad_fn=<AddBackward0>)
# The loss is  tensor(5600.4570, grad_fn=<AddBackward0>)
# The loss is  tensor(4668.4331, grad_fn=<AddBackward0>)
# The loss is  tensor(4503.2031, grad_fn=<AddBackward0>)
# The loss is  tensor(5370.1533, grad_fn=<AddBackward0>)
# The loss is  tensor(4571.9165, grad_fn=<AddBackward0>)
# The loss is  tensor(3656.1282, grad_fn=<AddBackward0>)
# The loss is  tensor(3703.6355, grad_fn=<AddBackward0>)
# The loss is  tensor(3460.8921, grad_fn=<AddBackward0>)
# The loss is  tensor(3862.0979, grad_fn=<AddBackward0>)
# The loss is  tensor(3694.2256, grad_fn=<AddBackward0>)
# The loss is  tensor(3484.3306, grad_fn=<AddBackward0>)
# The loss is  tensor(3619.4580, grad_fn=<AddBackward0>)
# The loss is  tensor(3412.9922, grad_fn=<AddBackward0>)
# The loss is  tensor(3700.4109, grad_fn=<AddBackward0>)
# The loss is  tensor(3439.7078, grad_fn=<AddBackward0>)
# The loss is  tensor(6924.9067, grad_fn=<AddBackward0>)
# The loss is  tensor(7819.2617, grad_fn=<AddBackward0>)
# The loss is  tensor(7091.4497, grad_fn=<AddBackward0>)
# The loss is  tensor(7471.5547, grad_fn=<AddBackward0>)
# The loss is  tensor(7874.5645, grad_fn=<AddBackward0>)
# The loss is  tensor(8070.1826, grad_fn=<AddBackward0>)
# The loss is  tensor(7622.5298, grad_fn=<AddBackward0>)
# The loss is  tensor(6445.4702, grad_fn=<AddBackward0>)
# The loss is  tensor(5469.9678, grad_fn=<AddBackward0>)
# The loss is  tensor(6434.0391, grad_fn=<AddBackward0>)
# The loss is  tensor(6468.5435, grad_fn=<AddBackward0>)
# The loss is  tensor(6565.9165, grad_fn=<AddBackward0>)
# The loss is  tensor(5876.3789, grad_fn=<AddBackward0>)
# The loss is  tensor(6420.4565, grad_fn=<AddBackward0>)
# The loss is  tensor(7519.2021, grad_fn=<AddBackward0>)
# The loss is  tensor(6834.2842, grad_fn=<AddBackward0>)
# The loss is  tensor(6981.2480, grad_fn=<AddBackward0>)
# The loss is  tensor(6594.9219, grad_fn=<AddBackward0>)
# The loss is  tensor(6455.8525, grad_fn=<AddBackward0>)
# The loss is  tensor(6310.2300, grad_fn=<AddBackward0>)
# The loss is  tensor(6620.4468, grad_fn=<AddBackward0>)
# The loss is  tensor(6240.7988, grad_fn=<AddBackward0>)
# The loss is  tensor(7241.4985, grad_fn=<AddBackward0>)
# The loss is  tensor(7118.1143, grad_fn=<AddBackward0>)
# The loss is  tensor(6534.3340, grad_fn=<AddBackward0>)
# The loss is  tensor(7008.9062, grad_fn=<AddBackward0>)
# The loss is  tensor(6368.4463, grad_fn=<AddBackward0>)
# The loss is  tensor(6577.8008, grad_fn=<AddBackward0>)
# tensor([[ 954.4367, 1006.1284,  961.4982, 1153.1309, 1108.4946, 1527.8604,
#          1624.6410, 1590.4181, 2222.0469, 2510.1792, 2399.5991, 2334.9175,
#          2950.2554, 2776.1616, 2896.5149, 3067.7444, 2985.7588, 2947.6440,
#          1701.9631, 2183.4348, 2345.3467, 2320.7295, 2601.7017, 2002.8202,
#          2068.4326, 2507.2764, 2550.6628, 2928.1099, 2630.8464, 2968.7786,
#          2736.6914, 2715.4402, 2961.8713, 2544.9106, 2458.4521, 2204.8315,
#          1979.8721, 2210.6021, 1471.9382, 2402.9724, 1548.8807, 1414.9221,
#          1449.3228, 3650.0864, 3520.5002, 4267.9312, 4274.2017, 4273.4102,
#          3131.4231, 3162.3459, 3053.9712, 2025.7241, 1715.5747, 1798.0038,
#          2751.7773, 2437.9475, 2658.2598, 3863.7227, 3887.2327, 3703.4312,
#          3680.8518, 3611.0669, 3891.3350, 3510.7468, 2927.6748, 3030.0342,
#          2654.9429, 3021.2847, 2741.5103, 2453.7595]], grad_fn=<AddmmBackward>)

# %%
torch.save(reg_net.state_dict(), 'own_model/the_first_time.pt')

# %% [markdown]
# try not to resize the image, because it will make the generate point unaccurate

# %%
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

class regNet_2D(nn.Module):
    def __init__(self):
        #使用super()方法调用基类的构造器，即nn.Module.__init__(self)
        super(regNet_2D,self).__init__()
        # The first layer 
        # Input channels = 3, output channels = 6 ,,5x5 square convolution kernel
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1) 
        self.bn1=nn.BatchNorm2d(32)
        self.pool_1 = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.bn2=nn.BatchNorm2d(64)
        self.pool_2 = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        
        
        self.reg_1 = torch.nn.Linear(128 * 16 * 16, 70)
        self.reg_1_1 = torch.nn.Linear(70, 70)
        # self.reg_1_2 = torch.nn.Linear(70, 70)
        
        
        self.deconv1=nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2)
        self.bn_deconv1=nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1)
        self.bn4=nn.BatchNorm2d(64)
        self.reg_2 = torch.nn.Linear(64 * 17 * 17, 70)
        self.reg_2_1 = torch.nn.Linear(70, 70)
        # self.reg_2_2 = torch.nn.Linear(70, 70)
        #64 input features, 10 output features for our 10 defined classes
        # self.fc2 = torch.nn.Linear(78, 78)
        

        
        
    def forward(self,x,y,width_1, height_1,width_2, height_2):
        
        #Size changes from (3, height, weight) to (6, height, weight)
        x = F.relu(self.bn1(self.conv1(x)))
        #Size changes from (6, height, weight) to (6, height/2, weight/2)
        size_h = outputSize(height_1,3,2,1)
        size_w = outputSize(width_1,3,2,1)
        x = self.pool_1(x)
        size_h = outputSize(size_h,3,2,0)
        size_w = outputSize(size_w,3,2,0)
        x = F.relu(self.bn2(self.conv2(x)))
        size_h = outputSize(size_h,3,2,1)
        size_w = outputSize(size_w,3,2,1)
        x = self.pool_2(x)
        size_h = outputSize(size_h,3,2,0)
        size_w = outputSize(size_w,3,2,0)
        x = F.relu(self.conv3(x))
        size_h = outputSize(size_h,3,2,1)
        size_w = outputSize(size_w,3,2,1)
        #Reshape data to input to the input layer of the neural net
        #Size changes from (6, height/2, weight/2) to (1, 6*height/2*weight/2)
        #Recall that the -1 infers this dimension from the other given dimension
        x_1 = x.view(-1, 128 * size_h * size_w)
        #Computes the activation of the first fully connected layer
        #Size changes from (1, 4608) to (1, 78)
        self.reg_1 = torch.nn.Linear(128 * size_h * size_w, 70)
        x_1 = self.reg_1(x_1)
        
        
        x = F.relu(self.bn_deconv1(self.deconv1(x)))
        size_h = outputSize(size_h,3,2,0)
        size_w = outputSize(size_w,3,2,0)
        x = F.relu(self.bn4(self.conv4(x)))
        size_h = outputSize(size_h,3,2,1)
        size_w = outputSize(size_w,3,2,1)
        
        x_2 = x.view(-1, 64 * size_h * size_w)
        self.reg_2 = torch.nn.Linear(64 * size_h * size_w, 70)
        x_2 = self.reg_2(x_2)
        
        #### end of the first image
        
        ### the first guess using the samiliar network
        y = F.relu(self.bn1(self.conv1(y)))
        y = self.pool_1(y)
        y = F.relu(self.bn2(self.conv2(y)))
        y = self.pool_2(y)
        y = F.relu(self.conv3(y))
        
        y_1 = y.view(-1, 128 * 16 * 16)
        y_1 = self.reg_1(y_1)
        
        y = F.relu(self.bn_deconv1(self.deconv1(y)))
        y = F.relu(self.bn4(self.conv4(y)))
        y_2 = y.view(-1, 64 * 17 * 17)
        y_2 = self.reg_2(y_2)
        
        
        
        # x = F.relu(self.fc2(x))
        return x_1,x_2,y_1,y_2

    
# transform_1 = transforms.Compose([transforms.Resize([512,512]),transforms.ToTensor()""",transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))"""]) 

transform_1 = transforms.Compose([transforms.ToTensor()])


reg_net=regNet_2D()

from PIL import Image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

optimizer = optim.Adam(reg_net.parameters(), lr=1e-4)
loss = nn.L1Loss()# MSELoss可换为
for epoch in range(2):
    for i, data in enumerate(loader, 0):
        inputs = data
        # source_image = plt.imread(inputs[0])
        
        optimizer.zero_grad()
        source_image = Image.open(inputs[0]).convert('RGB')
        # image = transform_1(source_image).unsqueeze(0)
        width_1, height_1 = source_image.size
        
        
        source_image1 = transform_1(source_image)
        # image_tensor = source_image1.to(device, torch.float)
        # source_image1 = torch.from_numpy(source_image).float()
        # source_image1 = source_image1.type(torch.FloatTensor)
        image_tensor= source_image1.unsqueeze(0)
        
        image_tensor = Variable(image_tensor)
        
        
        
        target_image = Image.open(target_image_array[i]).convert('RGB')
        width_2, height_2 = target_image.size
        
        # image = transform_1(target_image).unsqueeze(0)
        target_image1 = transform_1(target_image)
        target_image_tensor= target_image1.unsqueeze(0)
        target_image_tensor = Variable(target_image_tensor)
        
        optimizer.zero_grad()
        
        
        
        x_1,x_2,y_1,y_2 = reg_net(image_tensor,target_image_tensor,width_1, height_1,width_2, height_2)
        # plt.imshow(image)
        # plt.imshow(target_image)
        source_image_landmark = source_image_landmarks[i]
        current = pd.read_csv(source_image_landmark)
        X = current['X']
        Y = current['Y']
        # X = X.transpose()
        X = torch.FloatTensor(X[:70])
        X = X.unsqueeze(0)
        
        Y = torch.FloatTensor(Y[:70])
        Y = Y.unsqueeze(0)
        loss_1 = loss(x_1, X)
        loss_2 = loss(x_2, Y)
        
        ######
        target_image_landmark = target_image_landmarks[i]
        current = pd.read_csv(target_image_landmark)
        X = current['X']
        Y = current['Y']
        
        X = torch.FloatTensor(X[:70])
        X = X.unsqueeze(0)
        
        Y = torch.FloatTensor(Y[:70])
        Y = Y.unsqueeze(0)
        
        loss_3 = loss(y_1, X)
        loss_4 = loss(y_2, Y)
        
        
        loss_all = loss_1+loss_2+loss_3+loss_4
        loss_all.backward()
        
        optimizer.step()
        print("The loss is ",loss_all)
        break
    break
    
print(x_1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-8ff71deef677> in <module>
#     147
#     148
# --> 149         x_1,x_2,y_1,y_2 = reg_net(image_tensor,target_image_tensor,width_1, height_1,width_2, height_2)
#     150         # plt.imshow(image)
#     151         # plt.imshow(target_image)
#
# ~\Anaconda3\envs\pytouch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-26-8ff71deef677> in forward(self, x, y, width_1, height_1, width_2, height_2)
#      74         size_w = outputSize(size_w,3,2,1)
#      75
# ---> 76         x_2 = x.view(-1, 64 * size_h * size_w)
#      77         self.reg_2 = torch.nn.Linear(64 * size_h * size_w, 70)
#      78         x_2 = self.reg_2(x_2)
#
# RuntimeError: shape '[-1, 93440]' is invalid for input of size 1529280
