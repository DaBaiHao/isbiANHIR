# %%
import torch
import torchvision
import torchvision.transforms as transforms
from PIL import Image
Image.MAX_IMAGE_PIXELS = None  # Disable DecompressionBombError
import pandas as pd
import os
import matplotlib.pyplot as plt
from skimage import io, transform
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
def read_csv_file():


    DATASET_MEDIUM_DIR = 'can_be_train.csv'
    Image.MAX_IMAGE_PIXELS = None

    imgs_dirs = []
    dataset_read_result = pd.read_csv(DATASET_MEDIUM_DIR)
    i = 0
    for each_img_dir, \
        each_landmarks_dir, \
        each_target_image, \
        each_target_landmarks, \
        each_status in zip(dataset_read_result['Source image'],
                           dataset_read_result['Source landmarks'],
                           dataset_read_result['Target image'],
                           dataset_read_result['Target landmarks'],
                           dataset_read_result['status']):
        each_img_dir = 'images/' + each_img_dir
        each_landmarks_dir = 'landmarks/' + each_landmarks_dir
        each_target_image = 'images/' + each_target_image
        each_target_landmarks = 'landmarks/' + each_target_landmarks

        dataset_read_result.set_value(index=i, col='Source image', value=each_img_dir)
        dataset_read_result.set_value(index=i, col='Source landmarks', value=each_landmarks_dir)
        dataset_read_result.set_value(index=i, col='Target image', value=each_target_image)
        dataset_read_result.set_value(index=i, col='Target landmarks', value=each_target_landmarks)

        imgs_dirs.append(each_img_dir)
        i = i + 1

    print(dataset_read_result['Source image'][1])
    print(imgs_dirs[1])
    return dataset_read_result


dataset_read_result = read_csv_file()

# the first 10
source_image_array = dataset_read_result['Source image']
target_image_array = dataset_read_result['Target image']
source_image_landmarks = dataset_read_result['Source landmarks']
target_image_landmarks = dataset_read_result['Target landmarks']
# Out:
# images/lung-lesion_2/scale-25pc/29-041-Izd2-w35-He-les2.jpg
# images/lung-lesion_2/scale-25pc/29-041-Izd2-w35-He-les2.jpg
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

class Generator(nn.Module):
    def __init__(self):
        #使用super()方法调用基类的构造器，即nn.Module.__init__(self)
        super(Generator,self).__init__()
        # The first layer 
        # Input channels = 3, output channels = 6 ,,5x5 square convolution kernel
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1) 
        self.bn1=nn.BatchNorm2d(32)
        self.pool_1 = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.bn2=nn.BatchNorm2d(64)
        self.pool_2 = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        
        
        self.reg_1 = torch.nn.Linear(128 * 16 * 16, 700)
        self.reg_1_1 = torch.nn.Linear(700, 70)
        # self.reg_1_2 = torch.nn.Linear(70, 70)
        
        
        self.deconv1=nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2)
        self.bn_deconv1=nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1)
        self.bn4=nn.BatchNorm2d(64)
        self.reg_2 = torch.nn.Linear(64 * 17 * 17, 700)
        self.reg_2_1 = torch.nn.Linear(700, 70)
        # self.reg_2_2 = torch.nn.Linear(70, 70)
        #64 input features, 10 output features for our 10 defined classes
        # self.fc2 = torch.nn.Linear(78, 78)
        
        ########### end of the first
        self.conv1_y = nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1) 
        self.bn1_y=nn.BatchNorm2d(32)
        self.pool_1_y = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        
        self.conv2_y = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.bn2_y = nn.BatchNorm2d(64)
        self.pool_2_y  = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
        self.conv3_y = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        
        self.reg_1_y = torch.nn.Linear(128 * 16 * 16, 70)
        self.reg_1_1_y = torch.nn.Linear(70, 70)
        
        self.deconv1_y = nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2)
        self.bn_deconv1_y = nn.BatchNorm2d(64)
        self.conv4_y = nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1)
        self.bn4_y=nn.BatchNorm2d(64)
        self.reg_2_y = torch.nn.Linear(64 * 17 * 17, 70)
        self.reg_2_1_y = torch.nn.Linear(70, 70)
        
        
    def forward(self,x,y):
        #Size changes from (3, height, weight) to (6, height, weight)
        x = F.relu(self.bn1(self.conv1(x)))
        #Size changes from (6, height, weight) to (6, height/2, weight/2)
        x = self.pool_1(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool_2(x)
        x = F.relu(self.conv3(x))
        #Reshape data to input to the input layer of the neural net
        #Size changes from (6, height/2, weight/2) to (1, 6*height/2*weight/2)
        #Recall that the -1 infers this dimension from the other given dimension
        x_1 = x.view(-1, 128 * 16 * 16)
        #Computes the activation of the first fully connected layer
        #Size changes from (1, 4608) to (1, 78)
        x_1 = self.reg_1(x_1)
        x_1 = self.reg_1_1(x_1)
        
        x = F.relu(self.bn_deconv1(self.deconv1(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x_2 = x.view(-1, 64 * 17 * 17)
        x_2 = self.reg_2(x_2)
        x_2 = self.reg_2_1(x_2)
        #### end of the first image
        
        ### the first guess using the samiliar network
        y = F.relu(self.bn1(self.conv1(y)))
        y = self.pool_1(y)
        y = F.relu(self.bn2(self.conv2(y)))
        y = self.pool_2(y)
        y = F.relu(self.conv3(y))
        
        y_1 = y.view(-1, 128 * 16 * 16)
        y_1 = self.reg_1(y_1)
        y_1 = self.reg_1_1(y_1)
        
        y = F.relu(self.bn_deconv1(self.deconv1(y)))
        y = F.relu(self.bn4(self.conv4(y)))
        y_2 = y.view(-1, 64 * 17 * 17)
        y_2 = self.reg_2(y_2)
        y_2 = self.reg_2_1(y_2)
        
        
        # x = F.relu(self.fc2(x))
        return x_1,x_2,y_1,y_2

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator,self).__init__()
        
        self.reg_1_1 = torch.nn.Linear(70, 700)
        self.reg_1_2 = torch.nn.Linear(70, 700)
        self.reg_2_1 = torch.nn.Linear(70, 700)
        self.reg_2_2 = torch.nn.Linear(70, 700)
        self.cos_1 = nn.CosineSimilarity(eps=1e-6)
        self.cos_2 = nn.CosineSimilarity(eps=1e-6)
        
        self.dense_1 = torch.nn.Linear(1, 1)
        self.dense_2 = torch.nn.Linear(1, 1)
        
        self.sigmoid1 = nn.Sigmoid()
        self.sigmoid2 = nn.Sigmoid()
        self.sigmoid3 = nn.Sigmoid()
    def forward(self,x_1,x_2,y_1,y_2):
        
        x_1 = self.reg_1_1(x_1)
        x_2 = self.reg_1_2(x_2)
        y_1 = self.reg_2_1(y_1)
        y_2 = self.reg_2_2(y_2)
        x = self.cos_1(x_1,y_1)
        y = self.cos_2(x_2,y_2)
        
        x = self.dense_1(x)
        y = self.dense_2(y)
        
        # print(x)
        output = self.sigmoid1(x)+self.sigmoid2(y)
        output = self.sigmoid3(output)
        return output

# %%
transform_1 = transforms.Compose([transforms.Resize([512,512]),
                                  transforms.ToTensor()])

loader = torch.utils.data.DataLoader(source_image_array, batch_size=1,shuffle=True, num_workers=2)
generator=Generator()
discriminator=Discriminator()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

optimizerG = optim.Adam(generator.parameters(), lr=1e-4)
optimizerD = optim.Adam(discriminator.parameters(), lr=1e-4)

# Establish convention for real and fake labels during training
real_label = 1
fake_label = 0

loss = nn.MSELoss()# MSELoss可换为
criterion = nn.BCELoss()

print("Starting Training Loop...")
for epoch in range(100):
    print("Begin ",epoch,"epoch")
    for i, data in enumerate(loader, 0):
        # print("Begin ",epoch,"epoch")
        inputs = data
        # source_image = plt.imread(inputs[0])
        
        ## Train with all-real batch
        discriminator.zero_grad()
        label = torch.full((1,), real_label)
        
        
        source_image_landmark = source_image_landmarks[i]
        current = pd.read_csv(source_image_landmark)
        source_X = current['X']
        source_Y = current['Y']
#         # X = X.transpose()
        source_X = torch.FloatTensor(source_X[:70])
        source_X = source_X.unsqueeze(0)
        
        source_Y = torch.FloatTensor(source_Y[:70])
        source_Y = source_Y.unsqueeze(0)

        target_image_landmark = target_image_landmarks[i]
        current = pd.read_csv(target_image_landmark)
        target_X = current['X']
        target_Y = current['Y']
        
        target_X = torch.FloatTensor(target_X[:70])
        target_X = target_X.unsqueeze(0)
        
        target_Y = torch.FloatTensor(target_Y[:70])
        target_Y = target_Y.unsqueeze(0)

        output = discriminator(source_X,source_Y,target_X,target_Y).view(-1)
        # print(output)
        # Calculate loss on all-real batch
        errD_real = criterion(output,label)    
        # Calculate gradients for D in backward pass
        errD_real.backward(retain_graph=True)
        D_x = output.mean().item()
        
        
        
        ## Train with all-fake batch
        
        source_image = Image.open(inputs[0]).convert('RGB')
        source_image1 = transform_1(source_image)
        image_tensor= source_image1.unsqueeze(0)    
        image_tensor = Variable(image_tensor)
        target_image = Image.open(target_image_array[i]).convert('RGB')
        target_image1 = transform_1(target_image)
        target_image_tensor= target_image1.unsqueeze(0)
        target_image_tensor = Variable(target_image_tensor)
        x_1,x_2,y_1,y_2 = generator(image_tensor,target_image_tensor)
        label.fill_(fake_label)
        
        output = discriminator(x_1,x_2,y_1,y_2).view(-1)
        errD_fake = criterion(output, label)
        errD_fake.backward(retain_graph=True)
        D_G_z1 = output.mean().item()
        
        errD = errD_real + errD_fake
        optimizerD.step()
        
        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        generator.zero_grad()
        label.fill_(real_label)  # fake labels are real for generator cost
        output = discriminator(x_1,x_2,y_1,y_2).view(-1)
        errG = criterion(output, label)
        errG.backward(retain_graph=True)
        D_G_z2 = output.mean().item()
        # Update G
        optimizerG.step()

        print(errG)
# Out:
# Starting Training Loop...
# Begin  0 epoch
# tensor(0.2426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2361, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2346, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2334, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2352, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2352, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2339, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2344, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2340, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2339, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2339, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2354, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2347, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2336, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2347, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2345, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2336, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2335, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2345, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2335, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2340, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2342, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2342, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2369, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2346, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2346, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2335, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2347, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2346, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2357, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2364, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2357, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2380, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2353, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2356, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2360, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2361, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2353, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2357, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2359, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2364, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2366, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2365, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2365, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2366, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2368, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2370, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2373, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2374, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2373, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2376, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2377, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2377, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2378, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2382, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2382, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2379, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2381, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2379, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2377, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2381, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2381, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2378, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2378, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2379, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2378, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2377, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2380, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2375, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2377, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2376, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2377, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2374, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2373, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2371, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2367, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2366, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2362, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2358, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2356, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2352, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2349, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2344, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2342, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2338, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2335, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2332, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2333, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2330, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2328, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2325, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2317, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2326, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2328, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  1 epoch
# tensor(0.2331, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2333, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2336, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2337, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2340, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2342, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2345, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2347, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2350, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2352, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2356, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2358, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2360, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2363, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2365, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2367, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2369, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2372, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2374, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2376, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2378, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2380, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2382, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2383, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2383, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2385, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2386, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2388, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2389, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2389, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2393, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2393, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2394, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2394, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2393, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2393, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2393, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2394, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2395, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2395, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2397, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2397, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2398, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2398, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2399, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2400, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2401, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2402, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2403, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2404, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2406, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2407, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2408, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2410, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2411, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2412, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2413, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2415, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2416, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2417, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2418, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2419, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2420, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2420, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2423, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2423, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2424, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2425, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2425, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2425, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2425, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2425, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2428, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2428, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.
grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.3711, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4216, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4229, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4240, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.3759, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.3724, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.3731, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.3717, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.3715, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4234, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4232, grad_fn=<BinaryCrossEntropyBackward>)

# %%
torch.save(generator.state_dict(), 'own_model/the_gan_generator.pt')
torch.save(discriminator.state_dict(), 'own_model/the_gan_discriminator.pt')

# %%
for epoch in range(100):
    print("Begin ",epoch,"epoch")
    for i, data in enumerate(loader, 0):
        # print("Begin ",epoch,"epoch")
        inputs = data
        # source_image = plt.imread(inputs[0])
        
        ## Train with all-real batch
        discriminator.zero_grad()
        label = torch.full((1,), real_label)
        
        
        source_image_landmark = source_image_landmarks[i]
        current = pd.read_csv(source_image_landmark)
        source_X = current['X']
        source_Y = current['Y']
#         # X = X.transpose()
        source_X = torch.FloatTensor(source_X[:70])
        source_X = source_X.unsqueeze(0)
        
        source_Y = torch.FloatTensor(source_Y[:70])
        source_Y = source_Y.unsqueeze(0)

        target_image_landmark = target_image_landmarks[i]
        current = pd.read_csv(target_image_landmark)
        target_X = current['X']
        target_Y = current['Y']
        
        target_X = torch.FloatTensor(target_X[:70])
        target_X = target_X.unsqueeze(0)
        
        target_Y = torch.FloatTensor(target_Y[:70])
        target_Y = target_Y.unsqueeze(0)

        output = discriminator(source_X,source_Y,target_X,target_Y).view(-1)
        # print(output)
        # Calculate loss on all-real batch
        errD_real = criterion(output,label)    
        # Calculate gradients for D in backward pass
        errD_real.backward(retain_graph=True)
        D_x = output.mean().item()
        
        
        
        ## Train with all-fake batch
        
        source_image = Image.open(inputs[0]).convert('RGB')
        source_image1 = transform_1(source_image)
        image_tensor= source_image1.unsqueeze(0)    
        image_tensor = Variable(image_tensor)
        target_image = Image.open(target_image_array[i]).convert('RGB')
        target_image1 = transform_1(target_image)
        target_image_tensor= target_image1.unsqueeze(0)
        target_image_tensor = Variable(target_image_tensor)
        x_1,x_2,y_1,y_2 = generator(image_tensor,target_image_tensor)
        label.fill_(fake_label)
        
        output = discriminator(x_1,x_2,y_1,y_2).view(-1)
        errD_fake = criterion(output, label)
        errD_fake.backward(retain_graph=True)
        D_G_z1 = output.mean().item()
        
        errD = errD_real + errD_fake
        optimizerD.step()
        
        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        generator.zero_grad()
        label.fill_(real_label)  # fake labels are real for generator cost
        output = discriminator(x_1,x_2,y_1,y_2).view(-1)
        errG = criterion(output, label)
        errG.backward(retain_graph=True)
        D_G_z2 = output.mean().item()
        # Update G
        optimizerG.step()

        print(errG)
# Out:
# Begin  0 epoch
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5424, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5424, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5424, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5425, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  1 epoch
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5424, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6618, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  2 epoch
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5421, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5421, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5421, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6620, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  3 epoch
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  4 epoch
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6621, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  5 epoch
# tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5421, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5421, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5421, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  6 epoch
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4280, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5423, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4283, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  7 epoch
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5426, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5427, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4287, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  8 epoch
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4290, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4294, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5431, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5432, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5432, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4293, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4293, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5431, grad_fn=<BinaryCrossEntropyBackward>)
# ...
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5328, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5327, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5327, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5327, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5326, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5326, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5326, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5326, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  98 epoch
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5480, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6678, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5481, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5484, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5484, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5484, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5484, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5324, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5484, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5484, grad_fn=<BinaryCrossEntropyBackward>)
# Begin  99 epoch
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5325, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5325, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5486, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5486, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5323, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5322, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5485, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5321, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5321, grad_fn=<BinaryCrossEntropyBackward>)

# %%
def read_csv_file():


    DATASET_MEDIUM_DIR = 'dataset_medium.csv'
    Image.MAX_IMAGE_PIXELS = None

    imgs_dirs = []
    dataset_read_result = pd.read_csv(DATASET_MEDIUM_DIR)
    i = 0
    for each_img_dir, \
        each_landmarks_dir, \
        each_target_image, \
        each_target_landmarks, \
        each_status in zip(dataset_read_result['Source image'],
                           dataset_read_result['Source landmarks'],
                           dataset_read_result['Target image'],
                           dataset_read_result['Target landmarks'],
                           dataset_read_result['status']):
        each_img_dir = 'images/' + each_img_dir
        each_landmarks_dir = 'landmarks/' + each_landmarks_dir
        each_target_image = 'images/' + each_target_image
        each_target_landmarks = 'landmarks/' + each_target_landmarks

        dataset_read_result.set_value(index=i, col='Source image', value=each_img_dir)
        dataset_read_result.set_value(index=i, col='Source landmarks', value=each_landmarks_dir)
        dataset_read_result.set_value(index=i, col='Target image', value=each_target_image)
        dataset_read_result.set_value(index=i, col='Target landmarks', value=each_target_landmarks)

        imgs_dirs.append(each_img_dir)
        i = i + 1

    print(dataset_read_result['Source image'][1])
    print(imgs_dirs[1])
    return dataset_read_result

DATASET_MEDIUM_result = read_csv_file()

# the first 10
DATASET_MEDIUM_source_image_array = DATASET_MEDIUM_result['Source image']
DATASET_MEDIUM_target_image_array = DATASET_MEDIUM_result['Target image']
DATASET_MEDIUM_source_image_landmarks = DATASET_MEDIUM_result['Source landmarks']
DATASET_MEDIUM_target_image_landmarks = DATASET_MEDIUM_result['Target landmarks']
# Out:
# images/COAD_01/scale-25pc/S3.jpg
# images/COAD_01/scale-25pc/S3.jpg
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Administrator\Anaconda3\envs\pytouch\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
test_loader = torch.utils.data.DataLoader(DATASET_MEDIUM_source_image_array, batch_size=1,shuffle=True, num_workers=2)

# %%
import datetime

for i, data in enumerate(test_loader, 0):
    inputs = data
    
    source_image = Image.open(inputs[0]).convert('RGB')
    source_image1 = transform_1(source_image)
    image_tensor= source_image1.unsqueeze(0)    
    image_tensor = Variable(image_tensor)
    
    target_image = Image.open(DATASET_MEDIUM_target_image_array[i]).convert('RGB')
    target_image1 = transform_1(target_image)
    target_image_tensor= target_image1.unsqueeze(0)
    target_image_tensor = Variable(target_image_tensor)
    
    is_true = 0
    starttime = datetime.datetime.now()
    x_1,x_2,y_1,y_2 = generator(image_tensor,target_image_tensor)
    endtime = datetime.datetime.now()
    
    to_csv(x_1,x_2,y_1,y_2,i)
    print (endtime - starttime).seconds
    break

# %%
import pandas
range70 = range(70)
def to_csv(x_1,x_2,y_1,y_2,i):
    x_1_tocsv = x_1.detach().numpy()
    x_1_tocsv = x_1_tocsv[0]
    #print(x_1_tocsv)

    x_2_tocsv = x_2.detach().numpy()
    x_2_tocsv = x_2_tocsv[0]
    #print(x_2_tocsv)

    y_2_tocsv = y_2.detach().numpy()
    y_2_tocsv = y_2_tocsv[0]
    #print(y_2_tocsv)

    y_1_tocsv = y_1.detach().numpy()
    y_1_tocsv = y_1_tocsv[0]
    
    df = pandas.DataFrame(data={"": range70,"X": x_1_tocsv.astype(int), "Y": x_2_tocsv.astype(int)})
    source_dir = "real_result/source_landmark"+ str(i) +".csv"
    df.to_csv(source_dir, sep=',',index=False)
    
    df = pandas.DataFrame(data={"": range70,"X": y_1_tocsv.astype(int), "Y": y_2_tocsv.astype(int)})
    source_dir = "real_result/target_landmark"+ str(i) +".csv"
    df.to_csv(source_dir, sep=',',index=False)
